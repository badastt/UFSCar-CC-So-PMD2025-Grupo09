# %%
import requests
import os
import tarfile
import bibtexparser
import arxiv
import json
import re
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
import shutil
import ssl
import certifi
import urllib.request


download_dir = "arxiv_downloads"
extracted_dir = "arxiv_extracted"
output_dir = "papers"
os.makedirs(download_dir, exist_ok=True)
os.makedirs(extracted_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

MAX_BYTES = 9.9 * 1024 * 1024
chunk_index = 0

ssl_context = ssl.create_default_context(cafile=certifi.where())
original_urlopen = urllib.request.urlopen

def patched_urlopen(url, *args, **kwargs):
    if 'context' not in kwargs:
        kwargs['context'] = ssl_context
    return original_urlopen(url, *args, **kwargs)

urllib.request.urlopen = patched_urlopen

mined = set()
all_paper_ids = set()

import logging

bibtex_logger = logging.getLogger('bibtexparser')
bibtex_logger.setLevel(logging.CRITICAL)
bibtex_logger.propagate = False

# %%
chunks = list(Path("papers").glob("data_chunk_*.ndjson"))
chunk_index += len(chunks)

for chunk in chunks:
    with open(chunk, 'r', encoding='utf-8') as f:
        papers = [json.loads(line) for line in f]
        for p in papers:
            mined.add(p["id"])

client = arxiv.Client()

categories = [
    "cs.AI", "cs.AR", "cs.CC", "cs.CE", "cs.CG", "cs.CL", "cs.CR", "cs.CV", "cs.CY", "cs.DB"
]

categories = [  
                "cs.AI", "cs.AR", "cs.CC", "cs.CE", "cs.CG", "cs.CL", "cs.CR", "cs.CV", "cs.CY", "cs.DB",
                "cs.DC", "cs.DL", "cs.DM", "cs.DS", "cs.ET", "cs.FL", "cs.GL", "cs.GR", "cs.GT", "cs.HC",
                "cs.IR", "cs.IT", "cs.LG", "cs.LO", "cs.MA", "cs.MM", "cs.MS", "cs.NA", "cs.NE", "cs.NI",
                "cs.OH", "cs.OS", "cs.PF", "cs.PL", "cs.RO", "cs.SC", "cs.SD", "cs.SE", "cs.SI", "cs.SY",
                "econ.EM", "econ.GN", "econ.TH", "eess.AS", "eess.IV", "eess.SP", "eess.SY", "math.AC", "math.AG", "math.AP",
                "math.AT", "math.CA", "math.CO", "math.CT", "math.CV", "math.DG", "math.DS", "math.FA", "math.GM", "math.GN",
                "math.GR", "math.GT", "math.HO", "math.IT", "math.KT", "math.LO", "math.MG", "math.MP", "math.NA", "math.NT",
                "math.OA", "math.OC", "math.PR", "math.QA", "math.RA", "math.RT", "math.SG", "math.SP", "math.ST", "astro-ph.CO",
                "astro-ph.EP", "astro-ph.GA", "astro-ph.HE", "astro-ph.IM", "astro-ph.SR", "cond-mat.dis-nn", "cond-mat.mes-hall", "cond-mat.mtrl-sci", "cond-mat.other",
                "cond-mat.quant-gas", "cond-mat.soft", "cond-mat.stat-mech", "cond-mat.str-el", "cond-mat.supr-con", "gr-qc", "hep-ex", "hep-lat", "hep-ph", "hep-th",
                "math-ph", "nlin.AO", "nlin.CD", "nlin.CG", "nlin.PS", "nlin.SI", "nucl-ex", "nucl-th", "physics.acc-ph", "physics.ao-ph",
                "physics.app-ph", "physics.atm-clus", "physics.atom-ph", "physics.bio-ph", "physics.chem-ph", "physics.class-ph", "physics.comp-ph", "physics.data-an", "physics.ed-ph", "physics.flu-dyn",
                "physics.gen-ph", "physics.geo-ph", "physics.hist-ph", "physics.ins-det", "physics.med-ph", "physics.optics", "physics.plasm-ph", "physics.pop-ph", "physics.soc-ph", "physics.space-ph",
                "quant-ph", "q-bio.BM", "q-bio.CB", "q-bio.GN", "q-bio.MN", "q-bio.NC", "q-bio.OT", "q-bio.PE", "q-bio.QM", "q-bio.SC",
                "q-bio.TO", "q-fin.CP", "q-fin.EC", "q-fin.GN", "q-fin.MF", "q-fin.PM", "q-fin.PR", "q-fin.RM", "q-fin.ST", "q-fin.TR",
                "stat.AP", "stat.CO", "stat.ME", "stat.ML", "stat.OT", "stat.TH"
            ]

for n, c in enumerate(categories, 1):
    print(f"Fetching IDs for category {n} / {len(categories)}: {c}")
    search = arxiv.Search(
        query = f"cat:{c}",
        max_results=100,
        sort_by=arxiv.SortCriterion.SubmittedDate
    )
    try:
        results = client.results(search)
        for paper in results:
            pid = paper.entry_id.rsplit('/', 1)[-1].rsplit('v', 1)[0]
            all_paper_ids.add(pid)
    except Exception as e:
        print(f"Error fetching from category {c}: {e}")

all_paper_ids -= mined

print(f"Total paper IDs collected after removing repeated or mined: {len(all_paper_ids)}")
# Out:
# Fetching IDs for category 1 / 155: cs.AI
# Fetching IDs for category 2 / 155: cs.AR
# Fetching IDs for category 3 / 155: cs.CC
# Fetching IDs for category 4 / 155: cs.CE
# Fetching IDs for category 5 / 155: cs.CG
# Fetching IDs for category 6 / 155: cs.CL
# Fetching IDs for category 7 / 155: cs.CR
# Fetching IDs for category 8 / 155: cs.CV
# Fetching IDs for category 9 / 155: cs.CY
# Fetching IDs for category 10 / 155: cs.DB
# Fetching IDs for category 11 / 155: cs.DC
# Fetching IDs for category 12 / 155: cs.DL
# Fetching IDs for category 13 / 155: cs.DM
# Fetching IDs for category 14 / 155: cs.DS
# Fetching IDs for category 15 / 155: cs.ET
# Fetching IDs for category 16 / 155: cs.FL
# Fetching IDs for category 17 / 155: cs.GL
# Fetching IDs for category 18 / 155: cs.GR
# Fetching IDs for category 19 / 155: cs.GT
# Fetching IDs for category 20 / 155: cs.HC
# Fetching IDs for category 21 / 155: cs.IR
# Fetching IDs for category 22 / 155: cs.IT
# Fetching IDs for category 23 / 155: cs.LG
# Fetching IDs for category 24 / 155: cs.LO
# Fetching IDs for category 25 / 155: cs.MA
# Fetching IDs for category 26 / 155: cs.MM
# Fetching IDs for category 27 / 155: cs.MS
# Fetching IDs for category 28 / 155: cs.NA
# Fetching IDs for category 29 / 155: cs.NE
# Fetching IDs for category 30 / 155: cs.NI
# Fetching IDs for category 31 / 155: cs.OH
# Fetching IDs for category 32 / 155: cs.OS
# Fetching IDs for category 33 / 155: cs.PF
# Fetching IDs for category 34 / 155: cs.PL
# Fetching IDs for category 35 / 155: cs.RO
# Fetching IDs for category 36 / 155: cs.SC
# Fetching IDs for category 37 / 155: cs.SD
# Fetching IDs for category 38 / 155: cs.SE
# Fetching IDs for category 39 / 155: cs.SI
# Fetching IDs for category 40 / 155: cs.SY
# Fetching IDs for category 41 / 155: econ.EM
# Fetching IDs for category 42 / 155: econ.GN
# Fetching IDs for category 43 / 155: econ.TH
# Fetching IDs for category 44 / 155: eess.AS
# Fetching IDs for category 45 / 155: eess.IV
# Fetching IDs for category 46 / 155: eess.SP
# Fetching IDs for category 47 / 155: eess.SY
# Fetching IDs for category 48 / 155: math.AC
# Fetching IDs for category 49 / 155: math.AG
# Fetching IDs for category 50 / 155: math.AP
# Fetching IDs for category 51 / 155: math.AT
# Fetching IDs for category 52 / 155: math.CA
# Fetching IDs for category 53 / 155: math.CO
# Fetching IDs for category 54 / 155: math.CT
# Fetching IDs for category 55 / 155: math.CV
# Fetching IDs for category 56 / 155: math.DG
# Fetching IDs for category 57 / 155: math.DS
# Fetching IDs for category 58 / 155: math.FA
# Fetching IDs for category 59 / 155: math.GM
# Fetching IDs for category 60 / 155: math.GN
# Fetching IDs for category 61 / 155: math.GR
# Fetching IDs for category 62 / 155: math.GT
# Fetching IDs for category 63 / 155: math.HO
# Fetching IDs for category 64 / 155: math.IT
# Fetching IDs for category 65 / 155: math.KT
# Fetching IDs for category 66 / 155: math.LO
# Fetching IDs for category 67 / 155: math.MG
# Fetching IDs for category 68 / 155: math.MP
# Fetching IDs for category 69 / 155: math.NA
# Fetching IDs for category 70 / 155: math.NT
# Fetching IDs for category 71 / 155: math.OA
# Fetching IDs for category 72 / 155: math.OC
# Fetching IDs for category 73 / 155: math.PR
# Fetching IDs for category 74 / 155: math.QA
# Fetching IDs for category 75 / 155: math.RA
# Fetching IDs for category 76 / 155: math.RT
# Fetching IDs for category 77 / 155: math.SG
# Fetching IDs for category 78 / 155: math.SP
# Fetching IDs for category 79 / 155: math.ST
# Fetching IDs for category 80 / 155: astro-ph.CO
# Fetching IDs for category 81 / 155: astro-ph.EP
# Fetching IDs for category 82 / 155: astro-ph.GA
# Fetching IDs for category 83 / 155: astro-ph.HE
# Fetching IDs for category 84 / 155: astro-ph.IM
# Fetching IDs for category 85 / 155: astro-ph.SR
# Fetching IDs for category 86 / 155: cond-mat.dis-nn
# Fetching IDs for category 87 / 155: cond-mat.mes-hall
# Fetching IDs for category 88 / 155: cond-mat.mtrl-sci
# Fetching IDs for category 89 / 155: cond-mat.other
# Fetching IDs for category 90 / 155: cond-mat.quant-gas
# Fetching IDs for category 91 / 155: cond-mat.soft
# Fetching IDs for category 92 / 155: cond-mat.stat-mech
# Fetching IDs for category 93 / 155: cond-mat.str-el
# Fetching IDs for category 94 / 155: cond-mat.supr-con
# Fetching IDs for category 95 / 155: gr-qc
# Fetching IDs for category 96 / 155: hep-ex
# Fetching IDs for category 97 / 155: hep-lat
# Fetching IDs for category 98 / 155: hep-ph
# Fetching IDs for category 99 / 155: hep-th
# Fetching IDs for category 100 / 155: math-ph
# Fetching IDs for category 101 / 155: nlin.AO
# Fetching IDs for category 102 / 155: nlin.CD
# Fetching IDs for category 103 / 155: nlin.CG
# Fetching IDs for category 104 / 155: nlin.PS
# Fetching IDs for category 105 / 155: nlin.SI
# Fetching IDs for category 106 / 155: nucl-ex
# Fetching IDs for category 107 / 155: nucl-th
# Fetching IDs for category 108 / 155: physics.acc-ph
# Fetching IDs for category 109 / 155: physics.ao-ph
# Fetching IDs for category 110 / 155: physics.app-ph
# Fetching IDs for category 111 / 155: physics.atm-clus
# Fetching IDs for category 112 / 155: physics.atom-ph
# Fetching IDs for category 113 / 155: physics.bio-ph
# Fetching IDs for category 114 / 155: physics.chem-ph
# Fetching IDs for category 115 / 155: physics.class-ph
# Fetching IDs for category 116 / 155: physics.comp-ph
# Fetching IDs for category 117 / 155: physics.data-an
# Fetching IDs for category 118 / 155: physics.ed-ph
# Fetching IDs for category 119 / 155: physics.flu-dyn
# Fetching IDs for category 120 / 155: physics.gen-ph
# Fetching IDs for category 121 / 155: physics.geo-ph
# Fetching IDs for category 122 / 155: physics.hist-ph
# Fetching IDs for category 123 / 155: physics.ins-det
# Fetching IDs for category 124 / 155: physics.med-ph
# Fetching IDs for category 125 / 155: physics.optics
# Fetching IDs for category 126 / 155: physics.plasm-ph
# Fetching IDs for category 127 / 155: physics.pop-ph
# Fetching IDs for category 128 / 155: physics.soc-ph
# Fetching IDs for category 129 / 155: physics.space-ph
# Fetching IDs for category 130 / 155: quant-ph
# Fetching IDs for category 131 / 155: q-bio.BM
# Fetching IDs for category 132 / 155: q-bio.CB
# Fetching IDs for category 133 / 155: q-bio.GN
# Fetching IDs for category 134 / 155: q-bio.MN
# Fetching IDs for category 135 / 155: q-bio.NC
# Fetching IDs for category 136 / 155: q-bio.OT
# Fetching IDs for category 137 / 155: q-bio.PE
# Fetching IDs for category 138 / 155: q-bio.QM
# Fetching IDs for category 139 / 155: q-bio.SC
# Fetching IDs for category 140 / 155: q-bio.TO
# Fetching IDs for category 141 / 155: q-fin.CP
# Fetching IDs for category 142 / 155: q-fin.EC
# Fetching IDs for category 143 / 155: q-fin.GN
# Fetching IDs for category 144 / 155: q-fin.MF
# Fetching IDs for category 145 / 155: q-fin.PM
# Fetching IDs for category 146 / 155: q-fin.PR
# Fetching IDs for category 147 / 155: q-fin.RM
# Fetching IDs for category 148 / 155: q-fin.ST
# Fetching IDs for category 149 / 155: q-fin.TR
# Fetching IDs for category 150 / 155: stat.AP
# Fetching IDs for category 151 / 155: stat.CO
# Fetching IDs for category 152 / 155: stat.ME
# Fetching IDs for category 153 / 155: stat.ML
# Fetching IDs for category 154 / 155: stat.OT
# Fetching IDs for category 155 / 155: stat.TH
# Total paper IDs collected after removing repeated or mined: 5819

# %%
def process_paper(id):
    try:
        r = next(client.results(arxiv.Search(id_list=[id])))

        data = {}
        data['id'] = id
        data['link'] = r.entry_id
        data['last_update'] = r.updated.isoformat()
        data['published'] = r.published.isoformat()
        data['title'] = r.title
        data['authors'] = [str(a) for a in r.authors]
        data['summary'] = r.summary
        data['primary_category'] = r.primary_category
        data['categories'] = r.categories
        data['pre-print_link'] = f"http://arxiv.org/e-print/{id}"

        paper_path = os.path.join(download_dir, f"{id}.tar.gz")
        r.download_source(dirpath=download_dir, filename=f"{id}.tar.gz")

        extracted_path = os.path.join(extracted_dir, id)
        os.makedirs(extracted_path, exist_ok=True)

        try:
            with tarfile.open(paper_path, "r:gz") as tar:
                tar.extractall(path=extracted_path, filter='data')
    
            bib_entries = []
            for root, _, files in os.walk(extracted_path):
                for file in files:
                    if file.endswith('.bib'):
                        try:
                            with open(os.path.join(root, file), encoding='utf-8') as f:
                                parser = bibtexparser.bparser.BibTexParser(common_strings=True, ignore_nonstandard_types=True)
                                bib_db = bibtexparser.load(f, parser=parser)
                                bib_entries.extend(bib_db.entries)
                        except Exception as e:
                            print(f"{id} - .bib error: {e}")
            if bib_entries:
                data['bib'] = bib_entries
            else:
                for root, _, files in os.walk(extracted_path):
                    for file in files:
                        if file.endswith('.bbl'):
                            try:
                                with open(os.path.join(root, file), encoding='utf-8') as f:
                                    data['bbl'] = f.read()
                            except Exception as e:
                                print(f"{id} - .bbl error: {e}")
                            break
    
            for root, _, files in os.walk(extracted_path):
                for file in files:
                    if file.endswith('.tex'):
                        try:
                            with open(os.path.join(root, file), encoding='utf-8') as f:
                                tex = f.read()
                                if re.search(r"\*?\\documentclass\*?", tex):
                                    data['tex'] = tex
                                    break
                        except Exception as e:
                            print(f"{id} - .tex error: {e}")
        except:
            pass

        try:
            if os.path.exists(paper_path):
                os.remove(paper_path)
            if os.path.exists(extracted_path):
                shutil.rmtree(extracted_path)
        except Exception as e:
            print(f"{id} - cleanup error: {e}")

        return data

    except Exception as e:
        print(f"{id} - general error: {e}")
        return { "id": id, "error": str(e) }

all_data = {}

with ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(process_paper, pid) for pid in all_paper_ids]
    for future in as_completed(futures):
        result = future.result()
        pid = result.get("id", "[unknown]")

        if not result or "error" in result:
            continue
        
        if "error" not in result:
            all_data[pid] = result
            print(f"{pid}: {result.get('title', '[no title]')}")

            est_size = len(json.dumps(all_data, ensure_ascii=False).encode("utf-8"))

            print(f"{est_size} / {MAX_BYTES}")
            
            if est_size > MAX_BYTES:
                all_data.pop(pid)
                filename = os.path.join(output_dir, f"data_chunk_{chunk_index:03d}.ndjson")
                with open(filename, "w", encoding="utf-8") as f:
                    for paper_id, metadata in all_data.items():
                        metadata["id"] = paper_id
                        json.dump(metadata, f)
                        f.write("\n")
                chunk_index += 1
                all_data = {pid: result}
# Out:
# 2506.22711: Potential Customer Lifetime Value in Financial Institutions: The Usage Of Open Banking Data to Improve CLV Estimation
# 1597 / 10380902.4
# 2507.00074: Studying few cluster resonances with quantum neural network driven iterative Harrow-Hassidim-Lloyd algorithm
# 163476 / 10380902.4
# 2507.01818: Schauder-type estimates and applications
# 328137 / 10380902.4
# 2505.22519: Connectivity for quantum graphs via quantum adjacency operators
# 411414 / 10380902.4
# 2506.17935: Cost-Effective Optimization and Implementation of the CRT-Paillier Decryption Algorithm for Enhanced Performance
# 413831 / 10380902.4
# 2402.03059: Geometry controls diffusive target encounters and escape in tubular structures
# 526374 / 10380902.4
# 2506.10537: The pursuit of happiness
# 606094 / 10380902.4
# 2506.11746: Complex harmonic maps and rank 2 higher Teichmüller theory
# 984485 / 10380902.4
# 2407.11947: Spatiotemporal dynamics of ionic reorganization near biological membrane interfaces
# 1101754 / 10380902.4
# 2506.11313: Experimenting with Networks
# 1270170 / 10380902.4
# 2507.05356: Interaction-enhanced quantum to classical crossover temperature in a Luttinger liquid
# 1336983 / 10380902.4
# 2505.24394: Refining Platelet Purification Methods: Enhancing Proteomics for Clinical Applications
# 1339211 / 10380902.4
# 2504.20088: Deep Learning vs. Black-Scholes: Option Pricing Performance on Brazilian Petrobras Stocks
# 1394807 / 10380902.4
# 2506.02210: Exchangeability in Neural Network Architectures and its Application to Dynamic Pruning
# 1450997 / 10380902.4
# 2504.19243: Algorithmic Detection of Jacobi Stability for Systems of Second Order Differential Equations
# 1595943 / 10380902.4
# 2507.00450: Shell effects in quasi-fission for calcium induced reactions forming thorium isotopes
# 1728535 / 10380902.4
# 2507.03985: Ferroelectrically Switchable Half-Quantized Hall Effect
# 1730279 / 10380902.4
# 2507.01280 - .bib error: 'utf-8' codec can't decode byte 0xe4 in position 7871: invalid continuation byte
# 2507.01280: D-wave condensates and the landscape of the 2D Hubbard model
# 1762508 / 10380902.4
# 2507.06172: Learning Agile Tensile Perching for Aerial Robots from Demonstrations
# 1858506 / 10380902.4
# 2505.09951: SC*-Regular spaces and some functions
# 1924110 / 10380902.4
# 2507.04113: Hecke $L$-series for Sinha modules
# 2196703 / 10380902.4
# 2504.10470: Online Advanced Labs in Physics
# 2197932 / 10380902.4
# 2507.04389: Spinning black holes in astrophysical environments
# 2310031 / 10380902.4
# 2506.07394: The Lasso Distribution: Properties, Sampling Methods, and Applications in Bayesian Lasso Regression
# 2408918 / 10380902.4
# 2507.01685: Half Spatially Coupled Turbo-Like Codes
# 2462467 / 10380902.4
# 2507.05050: Measurement of the $ D^{0}\rightarrow K^{-}π^{+}e^{+}e^{-} $ branching fraction and search for $ D^{0}\rightarrow π^{+}π^{-}e^{+}e^{-} $ and $D^{0}\rightarrow K^{+}K^{-}e^{+}e^{-} $ decays at Belle
# 2518847 / 10380902.4
# 2507.03820: Perturbative renormalisation of the $Φ^4_{4-\varepsilon}$ model via generalized Wick maps
# 2579529 / 10380902.4
# 2506.22670: Quark Phase Space Distributions in Nuclei
# 2673662 / 10380902.4
# 2505.18296: Thermal and Turbulence Characteristics of Fast and Slow Coronal Mass Ejections at 1 AU
# 2769234 / 10380902.4
# 2503.09934: A Pharmacy Benefit Manager Insurance Business Model
# 2770718 / 10380902.4
# 2506.14172: On slice regular fractal-fractional Dirichlet type spaces
# 2845801 / 10380902.4
# 2411.08047: The Epistemology of Contemporary Physics: Classical Mechanics I
# 2919718 / 10380902.4
# 2506.22258: Mixing Time Bounds for the Gibbs Sampler under Isoperimetry
# 3068453 / 10380902.4
# 2503.15958: Multivariate Self-Exciting Processes with Dependencies
# 3195128 / 10380902.4
# 2506.02770: BPS polynomials and Welschinger invariants
# 3398506 / 10380902.4
# 2506.10781: Hazel Deriver: A Live Editor for Constructing Rule-Based Derivations
# 3428588 / 10380902.4
# 2506.15222: The Pitfalls and Potentials of Adding Gene-invariance to Optimal Mixing
# 3505957 / 10380902.4
# 2507.03584: Small Area Estimation of Fertility in Low- and Middle-Income Countries
# 3614719 / 10380902.4
# 2506.20903: Electric field-induced clustering in nanocomposite films of highly polarizable inclusions
# 3616657 / 10380902.4
# 2505.00172: Fourier--Mukai equivalences for formal groups and elliptic Hochschild homology
# 3618086 / 10380902.4
# 2506.01603: Vietoris--Rips Shadow for Euclidean Graph Reconstruction
# 3752353 / 10380902.4
# 2403.18401: Force generation by a cylindrical cell under stationary osmolytes synthesis
# 3833151 / 10380902.4
# 2506.21259: An isovariant Blakers--Massey theorem
# 3904454 / 10380902.4
# 2501.06398: VIX options in the SABR model
# 3961919 / 10380902.4
# 2506.17865 - .bib error: 'tcad'
# 2507.01109: HST pre-imaging of a free-floating planet candidate microlensing event
# 4125088 / 10380902.4
# 2506.10803: Solving Package Management via Hypergraph Dependency Resolution
# 4181941 / 10380902.4
# 2506.17865: LASA: Enhancing SoC Security Verification with LLM-Aided Property Generation
# 4254227 / 10380902.4
# 2506.19412: Community Detection in Energy Networks based on Energy Self-Sufficiency and Dynamic Flexibility Activation
# 4277859 / 10380902.4
# 2506.17112: Closed-Loop Molecular Communication with Local and Global Degradation: Modeling and ISI Analysis
# 4299207 / 10380902.4
# 2506.04412: Maps preserving the idempotency of Jordan products
# 4374336 / 10380902.4
# 2507.04554: Self-supervised learning of speech representations with Dutch archival data
# 4436095 / 10380902.4
# 2507.06565: The Flaws of Others: An LLM-driven Framework for Scientific Knowledge Production
# 4616922 / 10380902.4
# 2503.00320: Shifting Power: Leveraging LLMs to Simulate Human Aversion in ABMs of Bilateral Financial Exchanges, A bond market study
# 4714838 / 10380902.4
# 2507.04743: A description of classical field equations using extensions of graded Poisson brackets
# 4998378 / 10380902.4
# 2506.22859: On scaling factor for $^{28}$Si + $^{12}$C charge-changing cross sections at 90-1296 MeV/nucleon: Toward finding energy-dependent scaling factor for other elements
# 5065646 / 10380902.4
# 2411.12885: Time-resolved Coulomb explosion imaging of vibrational wave packets in alkali dimers on helium nanodroplets
# 5226608 / 10380902.4
# 2504.12319: Specialized text classification: an approach to classifying Open Banking transactions
# 5238743 / 10380902.4
# 2506.12177: A simplified and robust proxy-based approach for overcoming unmeasured confounding in EHR studies
# 5344885 / 10380902.4
# 2506.24126: Controlling the false discovery rate under a non-parametric graphical dependence model
# 5554567 / 10380902.4
# 2506.04246: Improving the average dilation of a metric graph by adding edges
# 5572818 / 10380902.4
# 2503.05963: Bayesian Graph Traversal
# 5704072 / 10380902.4
# 2507.03651: Analysing the Moments of the Determinant of a Random Matrix Via Analytic Combinatorics of Permutation Tables
# 5847933 / 10380902.4
# 2506.01249: SysLLMatic: Large Language Models are Software System Optimizers
# 6002558 / 10380902.4
# 2506.21262: Ambiguities, Built-in Biases and Flaws in Big Data Insight Extraction
# 6004920 / 10380902.4
# 2506.20694: Evaluating PDE discovery methods for multiscale modeling of biological signals
# 6055315 / 10380902.4
# 2507.00032: Ken Utilization Layer: Hebbian Replay Within a Student's Ken for Adaptive Knowledge Tracing
# 6094326 / 10380902.4
# 2506.23828: Acoustic-Assisted Fabrication of Thin Shells with Spatially Distributed Imperfections
# 6130573 / 10380902.4
# 2505.12002: Evolution of perturbed long nonlinear plane, ring and hybrid surface waves
# 6256701 / 10380902.4
# 2506.16397: New Bounds for the Ideal Proof System in Positive Characteristic
# 6517273 / 10380902.4
# 2505.10858: Generalized Kappa Distribution Function for Mixed Fermiom-Boson Quantum Plasmas
# 6518438 / 10380902.4
# 2506.10471: Contributions to conjectures on planar graphs: Induced Subgraphs, Treewidth, and Dominating Sets
# 6607661 / 10380902.4
# 2503.15670: Noise equals control
# 6768833 / 10380902.4
# 2501.12591: Optimal Rebate Design: Incentives, Competition and Efficiency in Auction Markets
# 6929398 / 10380902.4
# 2503.13193: The deep multi-FBSDE method: a robust deep learning method for coupled FBSDEs
# 7064708 / 10380902.4
# 2506.18170: On the Particle Image Overlap in Single Camera Defocusing Approaches
# 7217467 / 10380902.4
# 2506.14739: Repulsive particle interactions enable selective information processing at cellular interfaces
# 7473958 / 10380902.4
# 2505.12812: Connecting the Equinoctial Elements and Rodrigues Parameters: A New Set of Elements
# 7494622 / 10380902.4
# 2507.07478: Stability of rotating magnetic levitation
# 7541249 / 10380902.4
# 2506.00141: Quasilinear Wave "Reflection" Due to Proton Heating by an Imbalanced Turbulent Cascade
# 7542410 / 10380902.4
# 2507.04594: Exploring Core and Periphery Precepts in Biological and Artificial Intelligence: An Outcome-Based Perspective
# 7623725 / 10380902.4
# 2506.01354 - .tex error: 'utf-8' codec can't decode byte 0xb4 in position 4866: invalid start byte
# 2506.01354: Menelaus' and Ceva's theorems for translation triangles in Thurston geometries
# 7624712 / 10380902.4
# 2506.12914: Noise resilience of deterministic analog combinatorial optimization solvers
# 7745609 / 10380902.4
# 2506.14025: Modeling flying formations as flow-mediated matter
# 7931376 / 10380902.4
# 2506.21822: Putting Skill as Nearly Indistinguishable from Noise: An Empirical Bayes Analysis of PGA Tour Performance
# 7972568 / 10380902.4
# 2507.03994: Prediction of High-Temperature Half Quantum Anomalous Hall Effect in a Semi-magnetic Topological Insulator of MnBi$_2$Te$_4$/Sb$_2$Te$_3$
# 7974808 / 10380902.4
# 2506.10073: Patient-Specific Deep Reinforcement Learning for Automatic Replanning in Head-and-Neck Cancer Proton Therapy
# 8069148 / 10380902.4
# 2506.17135: No Scratch Quantum Computing by Reducing Qubit Overhead for Efficient Arithmetics
# 8090827 / 10380902.4
# 2507.05099: Real-Time Graph-based Point Cloud Networks on FPGAs via Stall-Free Deep Pipelining
# 8339568 / 10380902.4
# 2506.23811: Superconducting Ring Resonators: Modelling, Simulation, and Experimental Characterisation
# 8429377 / 10380902.4
# 2506.19996: Evolutionary dynamics of pairwise and group cooperation in heterogeneous social networks
# 8522441 / 10380902.4
# 2507.00004: A Theory of Inference Compute Scaling: Reasoning through Directed Stochastic Skill Search
# 8592185 / 10380902.4
# 2507.05393: Enhancing Underwater Images Using Deep Learning with Subjective Image Quality Integration
# 8647016 / 10380902.4
# 2506.09074: Fixed Points of Meir-Keeler and Leader Contractions with bounded orbits in b-Metric Spaces
# 8678674 / 10380902.4
# 2506.16604: Complete systems of solutions, transmutations and Darboux transform for Sturm-Liouville equations in impedance form
# 8772754 / 10380902.4
# 2506.17738: The tangle-valued 1-cocycle for knots
# 8834028 / 10380902.4
# 2505.24585: CHESS Compact Wiggler construction report
# 8835080 / 10380902.4
# 2504.21088: Temperature Mapping in Urban Biomes Using an Infrared Thermometer: An Investigative Approach to Physics Education
# 8837631 / 10380902.4
# 2402.05573: Research on the evolution of domestic multi-functional meter technology
# 8839932 / 10380902.4
# 2507.00774: Evaporation of sessile drops on a heated superhydrophobic substrate
# 8942496 / 10380902.4
# 2507.05728: Asynchronous Event Error-Minimizing Noise for Safeguarding Event Dataset
# 8974495 / 10380902.4
# 2507.07036: Modeling Heterogeneity across Varying Spatial Extents: Discovering Linkages between Sea Ice Retreat and Ice Shelve Melt in the Antarctic
# 9102784 / 10380902.4
# 2502.15597: From FAIR to CURE: Guidelines for Computational Models of Biological Systems
# 9243071 / 10380902.4
# 2504.16509: Solvability of the ${\rm SK}_1$-analog of the orthogonal groups
# 9243989 / 10380902.4
# 2506.13451: No-dimensional Tverberg-type problems
# 9320895 / 10380902.4
# 2503.21437: A Contextual Approach to Technological Understanding and Its Assessment
# 9322541 / 10380902.4
# 2505.20234 - .tex error: 'utf-8' codec can't decode byte 0xf6 in position 2254: invalid start byte
# 2505.20234: Derivations for the MPS overlap formulas of rational spin chains
# 9343677 / 10380902.4
# 2504.08910: Assessing Physics Students' Scientific Argumentation using Natural Language Processing
# 9439853 / 10380902.4
# 2503.16576: Propagation of optical solitons in the dielectric medium of a liquid crystal
# 9441740 / 10380902.4
# 2505.17934: Evaluating the impact of the L3 cache size of AMD EPYC CPUs on the performance of CFD applications
# 9545774 / 10380902.4
# 2506.08494: Multiversion of the Hausdorff--Young inequality
# 9696074 / 10380902.4
# 2505.22115: On an inverse problem for tree-like networks of elastic strings
# 9763913 / 10380902.4
# 2507.03897: GenAI-Powered Inference
# 13672936 / 10380902.4
# 2505.02712 - .bib error: 'nature'
# 2505.02712: Graph Neural Network-Based Reinforcement Learning for Controlling Biological Networks: The GATTACA Framework
# 4033353 / 10380902.4
# 2503.10451: The Willing Kingdon Clifford Algebra Library
# 4086369 / 10380902.4
# 2506.08803: Anisotropic area measures of convex bodies
# 4123879 / 10380902.4
# 2506.19069: 2D transverse laser cooling of a hexapole focused beam of cold BaF molecules
# 4227808 / 10380902.4
# 2503.20071: Primes via Zeros: Interactive Proofs for Testing Primality of Natural Classes of Ideals
# 4282137 / 10380902.4
# 2412.11336: Hierarchical cell identities emerge from animal gene regulatory mechanisms
# 4437556 / 10380902.4
# 2506.22647: Hyperuniformity in ternary fluid mixtures: the role of wetting and hydrodynamics
# 4534464 / 10380902.4
# 2507.03943: Atmospheric Turbulence-Resilient Long-Range Fourier Ptychography
# 4651505 / 10380902.4
# 2506.18117: Two-photon ionization of the K-shell of ions of the isonuclear sequence of a heavy atom
# 4652861 / 10380902.4
# 2505.07454: From Brain to Motion: Harnessing Higher-Derivative Mechanics for Neural Control
# 4654452 / 10380902.4
# 2504.18909: A presentation of the symmetric Grothendieck-Witt group of local rings over $\mathbb{F}_2$
# 4656705 / 10380902.4
# 2504.10537: Amelino-Camelia DSR effects on charged Dirac oscillators: Modulated spinning magnetic vortices
# 4696768 / 10380902.4
# 2507.01827: APRMCTS: Improving LLM-based Automated Program Repair with Iterative Tree Search
# 4824274 / 10380902.4
# 2503.18191: Enabling the Write-Back Page Cache with Strong Consistency in Distributed Userspace File Systems
# 4844874 / 10380902.4
# 2506.18062: Floating-Point Data Transformation for Lossless Compression
# 5028456 / 10380902.4
# 2507.01285: Far From Sight, Far From Mind: Inverse Distance Weighting for Graph Federated Recommendation
# 5063579 / 10380902.4
# 2504.19947: Nonlinear states of the conservative complex Swift-Hohenberg equation
# 5143904 / 10380902.4
# 2506.18251: Morse: Dual-Sampling for Lossless Acceleration of Diffusion Models
# 5276971 / 10380902.4
# 2507.01110: A LoD of Gaussians: Unified Training and Rendering for Ultra-Large Scale Reconstruction with External Memory
# 5386542 / 10380902.4
# 2506.10482: The LLLR generalised Langton's ant
# 5410615 / 10380902.4
# 2507.03909: A discontinuous Galerkin pressure correction scheme for the Oldroyd model of order one
# 5651142 / 10380902.4
# 2505.00572: A Bioinformatic Study of Genetics Involved in Determining Mild Traumatic Brain Injury Severity and Recovery
# 5653292 / 10380902.4
# 2507.03391: On the dynamics of affective states during play and the role of confusion
# 6064872 / 10380902.4
# 2506.11660: What Pareto-Efficiency Adjustments Cannot Fix
# 6122786 / 10380902.4
# 2506.13241: Scalable Simulation of Quantum Many-Body Dynamics with Or-Represented Quantum Algebra
# 6203870 / 10380902.4
# 2507.04997: Exploring O-RAN Compression Techniques in Decentralized Distributed MIMO Systems: Reducing Fronthaul Load
# 6269412 / 10380902.4
# 2507.04040: CSI-Free Symbol Detection for Atomic MIMO Receivers via In-Context Learning
# 6332363 / 10380902.4
# 2506.03386: Model for the Thermodynamics of Iron at High Pressures Near Melting
# 6418397 / 10380902.4
# 2504.09240: Monistic reduction of Einstein's Equation for self-gravitating field masses
# 6419873 / 10380902.4
# 2506.16131: An identity for generating series of deformations of multiple zeta values within an algebraic framework
# 6511441 / 10380902.4
# 2412.02452: Uncertain Regulations, Definite Impacts: The Impact of the US Securities and Exchange Commission's Regulatory Interventions on Crypto Assets
# 6512767 / 10380902.4
# 2504.08295: Exploring the Relationships Between the Divisors of Friends of $10$
# 6540591 / 10380902.4
# 2506.15041: Identifying economic narratives in large text corpora -- An integrated approach using Large Language Models
# 6629932 / 10380902.4
# 2506.03786: Discrete Element Parameter Calibration of Livestock Salt Based on Particle Scaling
# 6631846 / 10380902.4
# 2506.11533: Transformable Plasmonic Helix with Swinging Gold Nanoparticles
# 6633296 / 10380902.4
# 2506.04275: Self-organization to multicriticality
# 6690269 / 10380902.4
# 2507.05349: Infrared foundations for quantum geometry II: Catalogue of all torsion-like theories including new ghost-tachyon-free cases
# 6919825 / 10380902.4
# 2504.14475: Kuratowski Monoids on Posets
# 7010672 / 10380902.4
# 2507.05288: A Survey on Proactive Defense Strategies Against Misinformation in Large Language Models
# 7213391 / 10380902.4
# 2505.22134: Infection dynamics for fluctuating infection or removal rates regarding the number of infected and susceptible individuals
# 7215066 / 10380902.4
# 2505.14712: Lie Group Theory of Multipole Moments and Shape of Stationary Rotating Fluid Bodies
# 8194914 / 10380902.4
# 2506.16087: Consistency Verification in Ontology-Based Process Models with Parameter Interdependencies
# 8261135 / 10380902.4
# 2507.04201: An Efficient Max-Min Fair Resource Optimization Algorithm for Rate-Splitting Multiple Access
# 8381783 / 10380902.4
# 2506.09888: A strengthened bound on the number of states required to characterize maximum parsimony distance
# 8391088 / 10380902.4
# 2507.01119: Trade-Offs in EuBa2Cu3Oy Films containing Artificial Pinning Centers: Higher Critical Currents yet Faster Vortex Creep
# 8551930 / 10380902.4
# 2507.04410: Multimedia Verification Through Multi-Agent Deep Research Multimodal Large Language Models
# 8575915 / 10380902.4
# 2507.04918: A Simulation Framework for the LiteBIRD Instruments
# 8700075 / 10380902.4
# 2503.18675: Corporate Finance in the Age of Fintech: Scenarios and Challenges
# 8765060 / 10380902.4
# 2507.03444: Set Shaping Theory and the Foundations of Redundancy-Free Testable Codes
# 8767235 / 10380902.4
# 2507.02578: Human-Machine Collaboration and Ethical Considerations in Adaptive Cyber-Physical Systems
# 8842651 / 10380902.4
# 2504.18347: Tachyons Before Tachyons: Lev Strum (1890-1936) and Superluminal Velocities
# 8844369 / 10380902.4
# 2506.16162: Long Coalition Leads to Shrink? The Roles of Tipping and Technology-Sharing in Climate Clubs
# 9311180 / 10380902.4
# 2506.21713: Harnessing Piezoelectric Shear Actuators for Vibration Control in Sandwich Beams
# 9380994 / 10380902.4
# 2506.23206: Uncentered Fractional Maximal functions and mean oscillation spaces associated with dyadic Hausdorff content
# 9523956 / 10380902.4
# 2506.20218: On the $h$-majority dynamics with many opinions
# 9551194 / 10380902.4
# 2505.04313: KERAIA: An Adaptive and Explainable Framework for Dynamic Knowledge Representation and Reasoning
# 9708684 / 10380902.4
# 2505.15740: HybridProver: Augmenting Theorem Proving with LLM-Driven Proof Synthesis and Refinement
# 9804491 / 10380902.4
# 2003.01771: Artificial Intelligence, Chaos, Prediction and Understanding in Science
# 9867598 / 10380902.4
# 2507.05107: DICE: Discrete inverse continuity equation for learning population dynamics
# 10071009 / 10380902.4
# 2506.06479: Algorithmic Analysis of GTFS-RT vehicle position accuracy
# 10106692 / 10380902.4
# 2506.10772: Skillful joint probabilistic weather forecasting from marginals
# 10215692 / 10380902.4
# 2506.09536: Commissioning, characterization and first high dose rate irradiations at a compact X-ray tube for microbeam and minibeam radiation therapy
# 10353754 / 10380902.4
# 2505.24800: Strong coupling of chiral light with chiral matter: a macroscopic study
# 10488855 / 10380902.4
# 2507.07833: Fisher Score Matching for Simulation-Based Forecasting and Inference
# 204550 / 10380902.4
# 2506.23965: The Neighbour Sum Problem on Trees
# 243842 / 10380902.4
# 2504.15915: Topology and Diffeology via Metric-like Functions
# 379599 / 10380902.4
# 2410.23347: Can black holes be formed by focussing radiation?
# 420839 / 10380902.4
# 2507.01892: Simulation and analysis of turbulent flame and its effect on the wall of aero engine combustor
# 422295 / 10380902.4
# 2506.18029: Rational Motions of Minimal Quaternionic Degree with Prescribed Line Trajectories
# 490359 / 10380902.4
# 2506.23914: Learning robust parameter inference and density reconstruction in flyer plate impact experiments
# 764202 / 10380902.4
# 2506.19067: MEDEA: A Design-Time Multi-Objective Manager for Energy-Efficient DNN Inference on Heterogeneous Ultra-Low Power Platforms
# 792667 / 10380902.4
# 2505.15948: Citation Parsing and Analysis with Language Models
# 839449 / 10380902.4
# 2506.07244: Quantum SAT Problems with Finite Sets of Projectors are Complete for a Plethora of Classes
# 939013 / 10380902.4
# 2506.13117: Difference-differential fields of continuous functions
# 990291 / 10380902.4
# 2506.22871: P$^2$U: Progressive Precision Update For Efficient Model Distribution
# 1072761 / 10380902.4
# 2505.17264: Solving MDPs with LTLf+ and PPLTL+ Temporal Objectives
# 1148030 / 10380902.4
# 2004.07917: Knowledge Scientists: Unlocking the data-driven organization
# 1177784 / 10380902.4
# 2506.06791: How do higher-order interactions shape the energy landscape?
# 1247978 / 10380902.4
# 2507.02656: Volatile-rich evolution of molten super-Earth L 98-59 d
# 1374527 / 10380902.4
# 2507.02072: A novel two-stage parameter estimation framework integrating Approximate Bayesian Computation and Machine Learning: The ABC-RF-rejection algorithm
# 1417164 / 10380902.4
# 2502.11783: Femtosecond-and-atom-resolved solvation dynamics of a Na$^+$ ion in a helium nanodroplet
# 1558389 / 10380902.4
# 2505.13260: Some remarks on Quillen's Dévissage theorem
# 1613511 / 10380902.4
# 2507.00738: Murmurations of Modular Forms and $p$-power Coefficients
# 1709335 / 10380902.4
# 2504.03912: Nature of Science in the classroom: empirical insights into investigating physics
# 1711103 / 10380902.4
# 2506.17640: Empowering Iterative Graph Alignment Using Heat Diffusion
# 1738622 / 10380902.4
# 2507.03112: RLVER: Reinforcement Learning with Verifiable Emotion Rewards for Empathetic Agents
# 1962469 / 10380902.4
# 2506.18541: Deciding Termination of Simple Randomized Loops
# 1981192 / 10380902.4
# 2503.02923: Electron spin dynamics guide cell motility
# 1983177 / 10380902.4
# 2507.03090: Evolving Dark Sector and the Dark Dimension Scenario
# 2081252 / 10380902.4
# 2504.09471: Optional intervals event, sequential operation and their applications in physics, computer science and applied mathematics
# 2119878 / 10380902.4
# 2506.22544: An Algebraic Theory of Gapped Domain Wall Partons
# 2237788 / 10380902.4
# 2412.12100: Hawking for beginners
# 2257356 / 10380902.4
# 2505.09646: Temporal Interception and Present Reconstruction: A Cognitive-Signal Model for Human and AI Decision Making
# 2258742 / 10380902.4
# 2504.21551: Euclidean interval objects in categories with finite products
# 2369308 / 10380902.4
# 2503.15965: Practical Portfolio Optimization with Metaheuristics:Pre-assignment Constraint and Margin Trading
# 2370680 / 10380902.4
# 2504.09546: A simulation-heuristics dual-process model for intuitive physics
# 2439950 / 10380902.4
# 2501.13137: On the reproducibility of discrete-event simulation studies in health research: an empirical study using open models
# 2796195 / 10380902.4
# 2507.02111: How the Solar Dynamics Observatory Revolutionized our Physical Understanding of the Sun
# 2869362 / 10380902.4
# 2507.07662: A comprehensive study of bond bipolaron superconductivity in triangular lattice
# 2958602 / 10380902.4
# 2506.12023: On the validity of the Radon-Nikodym Theorem
# 2993717 / 10380902.4
# 2506.21512: Assessing an evolutionary search engine for small language models, prompts, and evaluation metrics
# 3063096 / 10380902.4
# 2505.07572: The strong Viterbo conjecture and various flavours of duality in Lagrangian products
# 3117239 / 10380902.4
# 2506.12420: Deterministic Lifting Theorems for One-Way Number-on-Forehead Communication
# 3156004 / 10380902.4
# 2507.03097: JWST's PEARLS: Temperatures of Nine Highly Magnified Stars in a Galaxy at Redshift z = 0.94 and Simulated Stellar Population Dependence on Stellar Metallicity and the Initial Mass Function
# 3324767 / 10380902.4
# 2504.15465: LithOS: An Operating System for Efficient Machine Learning on GPUs
# 3417858 / 10380902.4
# 2503.03777: FlexInfer: Breaking Memory Constraint via Flexible and Efficient Offloading for On-Device LLM Inference
# 3521940 / 10380902.4
# 2507.00370: A network-theoretic approach for characterizing Mack-mode instability in high-speed boundary layers
# 3601408 / 10380902.4
# 2506.22528: Abnormal and Contranormal L-Subgroups of an L-group
# 3681074 / 10380902.4
# 2506.14007: Hypersheaves and bases
# 3722049 / 10380902.4
# 2506.18494: Distribution of codewords on the faces of a hypercube and new combinatorial identities
# 3739163 / 10380902.4
# 2507.03895: TayFCS: Towards Light Feature Combination Selection for Deep Recommender Systems
# 3866404 / 10380902.4
# 2506.18512: MedTVT-R1: A Multimodal LLM Empowering Medical Reasoning and Diagnosis
# 4006715 / 10380902.4
# 2504.20162: Anti-localization of non-stationary quasi-waves in a $β$-FPUT chain
# 4085796 / 10380902.4
# 2507.00438: Linewidth narrowing and wideband frequency modulation of a DBR laser
# 4111416 / 10380902.4
# 2503.24201: An elementary question of Erdős and Graham
# 4112034 / 10380902.4
# 2507.00811: φ-Sectional curvature of statistical structures on almost contact metric manifolds
# 4166080 / 10380902.4
# 2506.05827: Ext-group in the category of quantum polynomial functors via the quantum Frobenius twist
# 4283309 / 10380902.4
# 2506.07238: Dirac spectral flow and Floer theory of hyperbolic three-manifolds
# 4389656 / 10380902.4
# 2506.21743: Storm Surge in Color: RGB-Encoded Physics-Aware Deep Learning for Storm Surge Forecasting
# 4489011 / 10380902.4
# 2506.10144: Physiological-Model-Based Neural Network for Heart Rate Estimation during Daily Physical Activities
# 4491397 / 10380902.4
# 2506.19139: SOF: Sorted Opacity Fields for Fast Unbounded Surface Reconstruction
# 4517075 / 10380902.4
# 2504.10252: MapperEEG: A Topological Approach to Brain State Clustering in EEG Recordings
# 4578710 / 10380902.4
# 2505.05121: Error Analysis of Deep PDE Solvers for Option Pricing
# 4630033 / 10380902.4
# 2507.01314 - .bib error: 'utf-8' codec can't decode byte 0xe9 in position 15917: invalid continuation byte
# 2507.01314: Semi-supervised learning for linear extremile regression
# 4718912 / 10380902.4
# 2507.07274 - .bib error: 'iccv'
# 2507.07274: LinguaMark: Do Multimodal Models Speak Fairly? A Benchmark-Based Evaluation
# 4770449 / 10380902.4
# 2505.08767: Strategy for Bayesian Optimized Beam Steering at TRIUMF-ISAC's MEBT and HEBT Beamlines
# 4817522 / 10380902.4
# 2507.03536: ACE: Automated Technical Debt Remediation with Validated Large Language Model Refactorings
# 5264766 / 10380902.4
# 2503.13399: MicroVQA: A Multimodal Reasoning Benchmark for Microscopy-Based Scientific Research
# 5319346 / 10380902.4
# 2506.21460: Wild refitting for black box prediction
# 5437682 / 10380902.4
# 2506.19497: The time course of visuo-semantic representations in the human brain is captured by combining vision and language models
# 5439397 / 10380902.4
# 2506.09019: Strong Watanabe-Yoshida conjecture for Complete Intersections
# 5551638 / 10380902.4
# 2506.15190: Learning Task-Agnostic Skill Bases to Uncover Motor Primitives in Animal Behaviors
# 5569175 / 10380902.4
# 2506.14247: Performance of the FARICH-based particle identification at charm superfactories using machine learning
# 5609771 / 10380902.4
# 2506.21670: Spontaneous Quantum Turbulence in a Newborn Bose-Einstein Condensate via the Kibble-Zurek Mechanism
# 5787438 / 10380902.4
# 2507.03978: Sensitive and accurate femtosecond pulse characterization via two-photon absorption in Fabry-Pérot laser diodes
# 5789653 / 10380902.4
# 2506.17451 - .bib error: 'tkdd'
# 2506.17451 - .bib error: 'tkdd'
# 2506.17451 - .bib error: 'vldbj'
# 2506.17451 - .bib error: 'icer23'
# 2412.12233: Russian roulette: Why you can have a deterministic potential-outcome framework, or an asymmetric utility function, but not both
# 5790886 / 10380902.4
# 2507.03381: Evaluation of an Uncertainty-Aware Late Fusion Algorithm for Multi-Source Bird's Eye View Detections Under Controlled Noise
# 6427925 / 10380902.4
# 2506.00896: Moduli space of Conformal Field Theories and non-commutative Riemannian geometry
# 6579040 / 10380902.4
# 2506.06025: Hinich's model for Day convolution revisited
# 6652249 / 10380902.4
# 2506.17451: Transient Concepts in Streaming Graphs
# 6692824 / 10380902.4
# 2507.00364: Machine Learning Accelerated Computational Surface-Specific Vibrational Spectroscopy Reveals Oxidation Level of Graphene in Contact with Water
# 6694578 / 10380902.4
# 2506.20402: Equilibrium Propagation for Periodic Dynamics
# 6776521 / 10380902.4
# 2412.08987: Isogeometric Analysis for the Pricing of Financial Derivatives with Nonlinear Models: Convertible Bonds and Options
# 7059696 / 10380902.4
# 2506.20321: Homology and cohomology of crossed products by inverse monoid actions and Steinberg algebras
# 7275417 / 10380902.4
# 2507.05072: Spherical Poisson Needlets with Shrinking Bandwidth
# 7391816 / 10380902.4
# 2502.03402: Tensor Evolution: A Framework for Fast Evaluation of Tensor Computations using Recurrences
# 7423361 / 10380902.4
# 2506.16732: On Training-Test (Mis)alignment in Unsupervised Combinatorial Optimization: Observation, Empirical Exploration, and Analysis
# 7435295 / 10380902.4
# 2506.19032: Prime simplicial complexes of finite groups
# 7527699 / 10380902.4
# 2506.08154: Generalised Orbifolds and G-equivariantisation
# 7630080 / 10380902.4
# 2507.06285: Broad-band Spectral Modeling of Prompt Emission from Gamma-Ray Bursts Observed by the Transiting Exoplanet Survey Satellite
# 7923636 / 10380902.4
# 2503.11940: Vote Delegation in DeFi Governance
# 7924890 / 10380902.4
# 2506.19670: Properties and Expressivity of Linear Geometric Centralities
# 8065869 / 10380902.4
# 2505.23364: Volume Entropy Rigidity for Random Groups at Low Densities
# 8199739 / 10380902.4
# 2507.00781 - .tex error: 'utf-8' codec can't decode byte 0xcf in position 380: invalid continuation byte
# 2507.00781: Permutation polynomials of the form $x+γ\mathrm{Tr}(H(x))$
# 8201158 / 10380902.4
# 2507.04953: Variability of hole spin qubits in planar Germanium
# 8422351 / 10380902.4
# 2507.06553: Tunable cavity coupling of a single SnV$^{-}$ center in nanodiamond across bad-emitter and bad-cavity regimes
# 8531871 / 10380902.4
# 2409.16786: Hierarchy of percolation patterns in a kinetic replication model
# 8635706 / 10380902.4
# 2505.20353: FastCache: Fast Caching for Diffusion Transformer Through Learnable Linear Approximation
# 8659568 / 10380902.4
# 2506.12289: Finite covers and strict boundary slopes of cusped hyperbolic 3-manifolds
# 8718358 / 10380902.4
# 2507.04150: Selberg's Central Limit Theorem weighted by Linear Statistics of Zeta Zeros
# 8791895 / 10380902.4
# 2503.03612: Large language models in finance : what is financial sentiment?
# 8793764 / 10380902.4
# 2503.23847: Einstein, tea leaves, meandering rivers, and the origin of supermassive black holes in ekpyrotic universe
# 8846608 / 10380902.4
# 2507.04728: Improved bounds on the $H$-rank of a mixed graph in terms of the matching number and fractional matching number
# 8939683 / 10380902.4
# 2405.04544: Applying the Iterative Development Process: The Creation of Fractal Emergence
# 8970319 / 10380902.4
# 2507.00634: Nonlinear projection-based model order reduction with machine learning regression for closure error modeling in the latent space
# 9082835 / 10380902.4
# 2506.16527: Physical complexity and black hole quantum computers
# 9127400 / 10380902.4
# 2507.02117: A Computational Proof of the Highest-Scoring Boggle Board
# 9128372 / 10380902.4
# 2505.05227: Something about the Mechanism of Induction Phenomena: The forgotten work of Berta de Haas-Lorentz on diamagnetism in superconductors
# 9176092 / 10380902.4
# 2507.06753: KAConvText: Novel Approach to Burmese Sentence Classification using Kolmogorov-Arnold Convolution
# 9177644 / 10380902.4
# 2501.11037: Toxicological Evaluation of Phytochemicals and Heavy Metals in Ficus exasperata Vahl (Sandpaper) Leaves obtained in Birnin Kebbi, Nigeria
# 9179609 / 10380902.4
# 2502.08264: Research on Cumin Peptides Using PBS Extraction and Their Multifunctional Bioactivities
# 9181735 / 10380902.4
# 2407.16719: A Brief Discussion on the Philosophical Principles and Development Directions of Data Circulation
# 9282775 / 10380902.4
# 2506.21475: Reinforcement Learning for Optimal Control of Spin Magnetometers
# 9370095 / 10380902.4
# 2504.06566: Diffusion Factor Models: Generating High-Dimensional Returns with Factor Structure
# 9675973 / 10380902.4
# 2506.20676: Achieving Gender Representation in Lead-Author Publications in the ASTRO3D Centre of Excellence
# 9677624 / 10380902.4
# 2507.03478: PhotIQA: A photoacoustic image data set with image quality ratings
# 9878713 / 10380902.4
# 2411.13813: The Value of Information from Sell-side Analysts
# 10118680 / 10380902.4
# 2507.03772: Skewed Score: A statistical framework to assess autograders
# 10210174 / 10380902.4
# 2506.20615: A New Regression Model for Analyzing Non-Stationary Extremes in Response and Covariate Variables with an Application in Meteorology
# 10279609 / 10380902.4
# 2507.00546: Inverse Design in Nanophotonics via Representation Learning
# 10390047 / 10380902.4
# 2506.01161: Invariant submodules of modular operators and Lomonosov type theorem for Hilbert C*-modules
# 172240 / 10380902.4
# 2506.11657: Fast parallel transient electromagnetic modeling using a uniform-in-time approximation to the exponential
# 245984 / 10380902.4
# 2506.14266: Controlling energy delivery with bistable nanostructures
# 338167 / 10380902.4
# 2506.17491: Exploring Strategies for Personalized Radiation Therapy Part II Predicting Tumor Drift Patterns with Diffusion Models
# 340257 / 10380902.4
# 2507.03670: Interaction Techniques that Encourage Longer Prompts Can Improve Psychological Ownership when Writing with AI
# 398491 / 10380902.4
# 2506.23956: Topological two-body interaction obstructing trivial ground states: an indicator of fractional Chern insulators
# 522367 / 10380902.4
# 2408.01470: SABR/LIBOR market models: pricing and calibration for some interest rate derivatives
# 637577 / 10380902.4
# 2506.04204: A Kernel-Based Approach for Accurate Steady-State Detection in Performance Time Series
# 737602 / 10380902.4
# 2506.15236: Fractal dimensions of complex networks: advocating for a topological approach
# 827756 / 10380902.4
# 2505.22669: Applications of certain probability distributions on positive integers
# 828368 / 10380902.4
# 2412.06669: Indigenous knowledges and kinship as a model for our future in outer space
# 858971 / 10380902.4
# 2505.10326: Facility based on electron linac LUE-40 -- current state and main research directions
# 860124 / 10380902.4
# 2506.08285: Imposing the Fundamental Dynamical Constraint of Hydrostatic Balance to Improve Global ML Weather Prediction
# 950006 / 10380902.4
# 2507.07375: Bradley-Terry and Multi-Objective Reward Modeling Are Complementary
# 1208974 / 10380902.4
# 2506.18560: Efficient Beam Selection for ISAC in Cell-Free Massive MIMO via Digital Twin-Assisted Deep Reinforcement Learning
# 1307399 / 10380902.4
# 2502.15868: Multilevel classification framework for breast cancer cell selection and its integration with advanced disease models
# 1309172 / 10380902.4
# 2507.05841: Cosmic-Ray Physics in the PeV to EeV Energy Range with the IceCube-Gen2 Surface Array (ICRC 2025)
# 1354193 / 10380902.4
# 2506.05288: Phase separation in a mixture of proliferating and motile active matter
# 1431111 / 10380902.4
# 2504.03797: A 2-Categorical Bridge Between Henkin Constructions and Lawvere's Fixed-Point Theorem: Unifying Completeness and Compactness
# 1540688 / 10380902.4
# 2506.11205: Interpolative Metrics Are Not New: A Study of Generalized Contractions in b-Suprametric Spaces
# 1593146 / 10380902.4
# 2505.19471: C*-like modules and matrix $p$-operator norms
# 1669594 / 10380902.4
# 2507.02449: Random dynamical systems for McKean--Vlasov SDEs via rough path theory
# 1852305 / 10380902.4
# 2505.16061: Internal and External Impacts of Natural Language Processing Papers
# 1888490 / 10380902.4
# 2506.02506: Classification of Hoyle State Decay Branches in Active Target Time Projection Chamber using Neural Network
# 1946080 / 10380902.4
# 2507.00750: Versatile multi-q antiferromagnetic charge order in correlated vdW metals
# 1947946 / 10380902.4
# 2507.04230: High-Resolution Sustain Pedal Depth Estimation from Piano Audio Across Room Acoustics
# 2042588 / 10380902.4
# 2506.20249: Language Modeling by Language Models
# 2298162 / 10380902.4
# 2507.05351: Instanton Moduli, Topology and the Bosonic/Heterotic String Origins
# 2360061 / 10380902.4
# 2507.04024: Exploring Exponential Runge-Kutta Methods: A Survey
# 2479298 / 10380902.4
# 2504.00488: Dynamical model-based experiment design for drug repositioning
# 2517064 / 10380902.4
# 2506.21706: A New Experimental Method for Determining the Pinning Energy of an Abrikosov Vortex
# 2562825 / 10380902.4
# 2502.17915: Dynamic Factor Model-Based Multiperiod Mean-Variance Portfolio Selection with Portfolio Constraints
# 2739133 / 10380902.4
# 2506.21385: Few-body bound states of bosonic mixtures in two-dimensional optical lattices
# 2830963 / 10380902.4
# 2505.03535: LHC operation and the High-Luminosity LHC upgrade project
# 2886539 / 10380902.4
# 2504.21004: A Categorical Integration of Quantifiers:A Higher Category Theoretic Perspective
# 2887959 / 10380902.4
# 2507.03405: Prompt Engineering Guidelines for Using Large Language Models in Requirements Engineering
# 3051101 / 10380902.4
# 2506.19859: SPP location with spherical ray tracing by refractive index
# 3053104 / 10380902.4
# 2503.11053: Pricing American Parisian Options under General Time-Inhomogeneous Markov Models
# 3237256 / 10380902.4
# 2506.01750: Warming from cold pools: A pathway for mesoscale organization to alter Earth's radiation budget
# 3346635 / 10380902.4
# 2506.05361: Scalable Generation of Spatial Transcriptomics from Histology Images via Whole-Slide Flow Matching
# 3381886 / 10380902.4
# 2506.19094: Accurate identification of communication between multiple interacting neural populations
# 3514756 / 10380902.4
# 2507.02481: Vertex-transitive nut graph order-degree existence problem
# 3622454 / 10380902.4
# 2507.03696: A minor planet in an outer resonance with Uranus
# 3623597 / 10380902.4
# 2503.00588: An Improved NSGA-II with local search for multi-objective energy-efficient flowshop scheduling problem
# 3625755 / 10380902.4
# 2506.14694: The homology torsion growth of determinantal hypertrees
# 3672309 / 10380902.4
# 2506.13515: Complexity of Coexistence Regions in the GRHT Map
# 3776776 / 10380902.4
# 2507.02606: De-AntiFake: Rethinking the Protective Perturbations Against Voice Cloning Attacks
# 3814321 / 10380902.4
# 2506.23599: Truncated symbols of differential symmetry breaking operators
# 4025350 / 10380902.4
# 2505.16150: Quantum $K$-theoretic divisor axiom for flag manifolds
# 4185149 / 10380902.4
# 2506.20842: Deciphering Chiral Superconductivity via Impurity Bound States
# 4251611 / 10380902.4
# 2507.03421: Hybrid-View Attention Network for Clinically Significant Prostate Cancer Classification in Transrectal Ultrasound
# 4291204 / 10380902.4
# 2503.18701: Spectral Analysis and Invariant Measure in Studies of the Dynamics of the Hemostasis of a Blood Vessel
# 4326205 / 10380902.4
# 2506.21771: Gradient-Based Neuroplastic Adaptation for Concurrent Optimization of Neuro-Fuzzy Networks
# 5155619 / 10380902.4
# 2506.14099: A break from the norm? Parametric representations of preference heterogeneity for discrete choice models in health
# 5157964 / 10380902.4
# 2507.07421: SynthEHR-Eviction: Enhancing Eviction SDoH Detection with LLM-Augmented Synthetic EHR Data
# 5378741 / 10380902.4
# 2104.05636: What Kind of Person Wins the Turing Award?
# 5423405 / 10380902.4
# 2507.02800: Time-Masked Transformers with Lightweight Test-Time Adaptation for Neural Speech Decoding
# 5506647 / 10380902.4
# 2507.06174 - .bib error: 'icra'
# 2507.06174: Fast Bilateral Teleoperation and Imitation Learning Using Sensorless Force Control via Accurate Dynamics Model
# 5597016 / 10380902.4
# 2506.03792: Analytical Reconstruction of Periodically Deformed Objects in Time-resolved CT
# 5622699 / 10380902.4
# 2506.09486: Definitions of the volume of a big cohomology class
# 5662868 / 10380902.4
# 2506.12726: Undecidability of Translational Tiling of the Plane with Orthogonally Convex Polyominoes
# 5769015 / 10380902.4
# 2507.00325: On quantum ergodicity for higher dimensional cat maps modulo prime powers
# 5824050 / 10380902.4
# 2507.04095: Human-centered AI with focus on Human-robot interaction (Book chapter)
# 5825655 / 10380902.4
# 2507.05578: The Landscape of Memorization in LLMs: Mechanisms, Measurement, and Mitigation
# 5942478 / 10380902.4
# 2506.08304: Long-range dispersal promotes spatial synchrony but reduces the length and time scales of synchronous fluctuations
# 6008602 / 10380902.4
# 2409.06496: Valuation Model of Chinese Convertible Bonds Based on Monte Carlo Simulation
# 6077224 / 10380902.4
# 2506.09579: Power Diagram Enhanced Adaptive Isosurface Extraction from Signed Distance Fields
# 6153622 / 10380902.4
# 2504.16771: Projective Variety Recovery from Unknown Linear Projections
# 6155523 / 10380902.4
# 2506.17373: A practical identifiability criterion leveraging weak-form parameter estimation
# 6255148 / 10380902.4
# 2506.03859: Accelerating Randomized Algorithms for Low-Rank Matrix Approximation
# 6357038 / 10380902.4
# 2507.03249: Nonlinear Seebeck effect in Ni$_{81}$Fe$_{19}$|Pt at room temperature
# 6434375 / 10380902.4
# 2505.01696: Interpretable graph-based models on multimodal biomedical data integration: A technical review and benchmarking
# 6436870 / 10380902.4
# 2502.01495: Supervised Similarity for High-Yield Corporate Bonds with Quantum Cognition Machine Learning
# 6523803 / 10380902.4
# 2506.20875: 3DGH: 3D Head Generation with Composable Hair and Face
# 6553978 / 10380902.4
# 2507.04233: Grid-Reg: Grid-Based SAR and Optical Image Registration Across Platforms
# 6666785 / 10380902.4
# 2505.06562: SC*-Normal spaces and some functions
# 6718054 / 10380902.4
# 2507.02127: Spectral coverings without embeddings
# 6757968 / 10380902.4
# 2506.21371: MAx-DNN: Multi-Level Arithmetic Approximation for Energy-Efficient DNN Hardware Accelerators
# 6808438 / 10380902.4
# 2506.20810: FINN-GL: Generalized Mixed-Precision Extensions for FPGA-Accelerated LSTMs
# 6850704 / 10380902.4
# 2507.07348: Zero-Shot Context Generalization in Reinforcement Learning from Few Training Contexts
# 6920943 / 10380902.4
# 2507.00213: The Hamiltonian surface of $\Aut(F_2)$
# 6997358 / 10380902.4
# 2506.16817: Theoretical novel medical isotope production with deuterium-tritium fusion technology
# 6999195 / 10380902.4
# 2507.02290: Best bounds for the dual Hardy operator minus identity on decreasing functions
# 7029155 / 10380902.4
# 2507.06556: Spectra of high-dimensional sparse random geometric graphs
# 7123272 / 10380902.4
# 2507.07453: Bluish Veil Detection and Lesion Classification using Custom Deep Learnable Layers with Explainable Artificial Intelligence (XAI)
# 7125285 / 10380902.4
# 2502.02691: Temperature-dependent radiative lifetime measurement of the $6^1Σ_g^+(v=9,J=31)$ state of sodium molecules
# 7195349 / 10380902.4
# 2506.12774: On the Vertices of Delta-modular Polyhedra
# 7313659 / 10380902.4
# 2504.13360: In between myth and reality: AI for math -- a case study in category theory
# 7354679 / 10380902.4
# 2504.06302: Spin Helicity and the Disproof of Bell's Theorem
# 7389374 / 10380902.4
# 2506.07469: Individual Treatment Effect: Prediction Intervals and Sharp Bounds
# 7513663 / 10380902.4
# 2507.03939: Study of Wormhole in $f(Q)$ gravity with some dark energy models
# 7578377 / 10380902.4
# 2506.20664: The Decrypto Benchmark for Multi-Agent Reasoning and Theory of Mind
# 7729889 / 10380902.4
# 2506.20292 - general error: HTTP Error 404: Not Found
# 2507.04367: Directional Flow of Confined Polaritons in CrSBr
# 8445702 / 10380902.4
# 2506.13655: The Word Problem for Products of Symmetric Groups
# 8548509 / 10380902.4
# 2504.13049: Multi-modal single-cell foundation models via dynamic token adaptation
# 9269443 / 10380902.4
# 2506.21870: Quasi-triangular and factorizable Poisson bialgebras
# 9385069 / 10380902.4
# 2505.10390: Operational and Exploration Requirements and Research Capabilities for SEP Environment Monitoring and Forecasting
# 9387168 / 10380902.4
# 2506.16171: Maximum Reachability Orientation of Mixed Graphs
# 9553750 / 10380902.4
# 2503.08272: Dynamically optimal portfolios for monotone mean--variance preferences
# 9711673 / 10380902.4
# 2506.12547: Endo-exo classification of episodic rock creep in deep mines: Implications for forecasting catastrophic failure
# 9714058 / 10380902.4
# 2505.11387: High brightness, symmetric electron bunch generation in a plasma wakefield accelerator via a radially-polarized plasma photocathode
# 9850543 / 10380902.4
# 2502.12912: A Simplified and Numerically Stable Approach to the BG/NBD Churn Prediction model
# 9867684 / 10380902.4
# 2504.02518: Online Multivariate Regularized Distributional Regression for High-dimensional Probabilistic Electricity Price Forecasting
# 10015065 / 10380902.4
# 2507.04260: Existence Theory for a class of semilinear mixed local and nonlocal equations involving variable singularities and singular measures
# 10093240 / 10380902.4
# 2507.03768: Entanglement transitions in structured and random nonunitary Gaussian circuits
# 10235459 / 10380902.4
# 2506.16838: Quantifying Flow State Dynamics: A Prefrontal Cortex EEG-Based Model Validation Study. Unveiling the Prefrontal Cortex's Role in Flow State Experience: An Empirical EEG Analysis
# 10237952 / 10380902.4
# 2506.20426: Modulated categories and their representations via higher categories
# 10292320 / 10380902.4
# 2506.07911: Stability and Extension of Steady and Ranging Persistence
# 10414160 / 10380902.4
# 2507.02149: Observation of orbitally excited $B_{c}^{+}$ states
# 702200 / 10380902.4
# 2505.04035: Demonstrating Dynamic Stability in Paul Traps: Exploring Rotating Saddles with Liquid Nitrogen Droplets
# 758206 / 10380902.4
# 2506.21329: Active Inference AI Systems for Scientific Discovery
# 835209 / 10380902.4
# 2506.18845: SocioXplorer: An Interactive Tool for Topic and Network Analysis in Social Data
# 868182 / 10380902.4
# 2507.04342: From $U(1) \times U(1)$ Symmetry Breaking to Majoron Cosmology: Insights from NANOGrav 15-year Data
# 1056955 / 10380902.4
# 2506.19377: A Unified Platform to Evaluate STDP Learning Rule and Synapse Model using Pattern Recognition in a Spiking Neural Network
# 1070561 / 10380902.4
# 2506.09061: EdgeProfiler: A Fast Profiling Framework for Lightweight LLMs on Edge Using Analytical Model
# 1150771 / 10380902.4
# 2506.07916: Refugees' path to legal stability is long and systematically unequal
# 1234606 / 10380902.4
# 2507.04616: Geodesic completeness, curvature singularities and infinite tidal forces
# 1285179 / 10380902.4
# 2411.12492: Recent advances in space sailing missions and technology: review of the 6th International Symposium on Space Sailing (ISSS 2023)
# 1381250 / 10380902.4
# 2506.12566 - .tex error: 'utf-8' codec can't decode byte 0x93 in position 1599: invalid start byte
# 2506.12566: Inferring Grain Size Distributions from Magnetic Hysteresis in M-type Hexaferrites
# 1382627 / 10380902.4
# 2506.03028: Protein Inverse Folding From Structure Feedback
# 1465384 / 10380902.4
# 2506.18838: Subgraph Entropy
# 1551097 / 10380902.4
# 2506.12763: Growth of entire functions: from frequent hypercyclicity to hypercyclicity for the differentiation operator
# 1596240 / 10380902.4
# 2505.11041: In silico tool for identification of colorectal cancer from cell-free DNA biomarkers
# 1598512 / 10380902.4
# 2505.19942: Vertical Profile Corrected Satellite NH3 Retrievals Enable Accurate Agricultural Emission Characterization in China
# 1601009 / 10380902.4
# 2506.13717: Contrastive Self-Supervised Learning As Neural Manifold Packing
# 1684999 / 10380902.4
# 2507.07114: Distributed Training under Packet Loss
# 1720966 / 10380902.4
# 2507.05821: On cubic vertex-transitive graphs of given girth
# 1793053 / 10380902.4
# 2506.05871: BestServe: Serving Strategies with Optimal Goodput in Collocation and Disaggregation Architectures
# 1941730 / 10380902.4
# 2507.07643: RIS-assisted ISAC Systems for Industrial Revolution 6.0: Exploring the Near-field and Far-field Coexistence
# 2088084 / 10380902.4
# 2506.20217: Ten simple rules for PIs to integrate Research Software Engineering into their research group
# 2145366 / 10380902.4
# 2506.15824: On the classification of $C^*$-algebras of twisted isometries with finite dimensional wandering spaces
# 2274874 / 10380902.4
# 2501.08356: A large population of cell-specific action potential models replicating fluorescence recordings of voltage in rabbit ventricular myocytes
# 2388028 / 10380902.4
# 2506.10544: Compatibility between truncation and coproducts for quantum affine algebra and Yangian of $\mathfrak{sl}_2(\mathbb{C})$
# 2433376 / 10380902.4
# 2506.13245: A Game-Theoretic Negotiation Framework for Cross-Cultural Consensus in LLMs
# 2620757 / 10380902.4
# 2505.06514: Direct space-time modeling of mechanically dressed dipole-dipole interactions with electromagnetically-coupled oscillating dipoles
# 2801405 / 10380902.4
# 2507.00859: On $L$-$ω$-nonexpansive maps
# 2873170 / 10380902.4
# 2503.03780: Weighted Combination and Singular Spectrum Analysis Based Remote Photoplethysmography Pulse Extraction in Low-light Environments
# 2943170 / 10380902.4
# 2507.05441: Adversarial Machine Learning Attacks on Financial Reporting via Maximum Violated Multi-Objective Attack
# 3059735 / 10380902.4
# 2506.19191: Bayesian Evolutionary Swarm Architecture: A Formal Epistemic System Grounded in Truth-Based Competition
# 3269325 / 10380902.4
# 2506.18486: J-ternary algebras, structurable algebras, and Lie superalgebras
# 3426811 / 10380902.4
# 2505.14000: On isomorphisms of semi-free Hamiltonian $S^1$-manifolds and fixed point data
# 3663603 / 10380902.4
# 2505.05167: Numerically modelling semidirect product geodesics
# 3852122 / 10380902.4
# 2507.01297: Frustratingly Simple Retrieval Improves Challenging, Reasoning-Intensive Benchmarks
# 3907564 / 10380902.4
# 2410.03552: Evaluating Investment Risks in LATAM AI Startups: Ranking of Investment Potential and Framework for Valuation
# 4029354 / 10380902.4
# 2503.17889: The complexities of falling freely
# 4030493 / 10380902.4
# 2507.06039: Enter, Exit, Page Fault, Leak: Testing Isolation Boundaries for Microarchitectural Leaks
# 4047188 / 10380902.4
# 2505.04235: Decommissioning and Post-Irradiation Examination of the LHC Beam Dumps
# 4172694 / 10380902.4
# 2506.22922: Global Predecessor Indexing: Avoiding Binary Search in Weighted Job Scheduling
# 4208397 / 10380902.4
# 2503.24175: What is the Funniest Number? An investigation of numerical humor
# 4239991 / 10380902.4
# 2507.02731: RIS-Aided Cooperative ISAC Networks for Structural Health Monitoring
# 4357865 / 10380902.4
# 2412.07348: IntraLayer: A Platform of Digital Finance Platforms
# 4497351 / 10380902.4
# 2503.18165: Agent-Based Models for Two Stocks with Superhedging
# 4721395 / 10380902.4
# 2506.22144: Wait-Only Broadcast Protocols are Easier to Verify
# 4740090 / 10380902.4
# 2506.06377: Evaluating Large Language Model Capabilities in Assessing Spatial Econometrics Research
# 4811294 / 10380902.4
# 2507.00168: Superconductivity induced by spin-orbit coupling in a two-valley ferromagnet
# 4902256 / 10380902.4
# 2505.00934: Bayesian Forensic DNA Mixture Deconvolution Using a Novel String Similarity Measure
# 5119721 / 10380902.4
# 2505.02681: Network analysis of student perceptions of an introductory lab
# 5356703 / 10380902.4
# 2507.00691: Minimum-enstrophy and maximum-entropy equilibrium states in two-dimensional topographic turbulence
# 5457937 / 10380902.4
# 2503.17103: Martingale property and moment explosions in signature volatility models
# 5628981 / 10380902.4
# 2506.09078: The spatially variable effects of mangroves on flood depths and losses from storm surges in Florida
# 5630536 / 10380902.4
# 2505.22223: Bayesian Learning in Structural Dynamics: A Comprehensive Review and Emerging Trends
# 5633028 / 10380902.4
# 2507.02266: A semi-analytical solution for the lubrication force between two spheres approaching in viscoelastic fluids described by the Oldroyd-B model under small Deborah numbers
# 5785104 / 10380902.4
# 2505.20224: Triangular and Unitriangular Factorization of Twisted Chevalley Groups
# 5885264 / 10380902.4
# 2506.15064: HiPreNets: High-Precision Neural Networks through Progressive Training
# 5965259 / 10380902.4
# 2507.01148: Non-unique equilibrium measures and freezing phase transitions for matrix cocycles for negative $t$
# 6057738 / 10380902.4
# 2506.04107: Risk and Reward of Transitioning from a National to a Zonal Electricity Market in Great Britain
# 6108255 / 10380902.4
# 2507.04550: Compact, intense attosecond sources driven by hollow Gaussian beams
# 6257870 / 10380902.4
# 2505.22665: Solutions of Analytical Systems of Partial Differential Equations
# 6258589 / 10380902.4
# 2507.07333: Scalable and Realistic Virtual Try-on Application for Foundation Makeup with Kubelka-Munk Theory
# 6298951 / 10380902.4
# 2507.06355: Density matrix analysis of systems influenced by periodic Hamiltonians
# 6372764 / 10380902.4
# 2506.03726: Introducing multiverse analysis to bibliometrics: The case of team size effects on disruptive research
# 6374552 / 10380902.4
# 2507.03778: Bekenstein-Hawking Entropy: A Brief Overview
# 6422845 / 10380902.4
# 2502.19305: Corporate Fraud Detection in Rich-yet-Noisy Financial Graph
# 6518906 / 10380902.4
# 2505.03092: Uma breve história do spin
# 6729190 / 10380902.4
# 2504.05701: On (Some) Gauge Theories of Gravity
# 6790777 / 10380902.4
# 2506.19568: Time-Sensitive Importance Splitting
# 6827191 / 10380902.4
# 2507.04166: Governance and Technological Challenge in Digital Solidarity Economies: A Case Study of a Collaborative Transportation Platform in South Korea
# 6828998 / 10380902.4
# 2507.05062: A Corrective Frequency-Constrained Unit Commitment with Data-driven Estimation of Optimal UFLS in Island Power Systems
# 6897046 / 10380902.4
# 2506.22996: Some results about varextropy and weighted varextropy functions
# 6966885 / 10380902.4
# 2503.06409: Reflection of Phase Anisotropy on Molecule
# 9219360 / 10380902.4
# 2503.16753: EarlyStopping: Implicit Regularization for Iterative Learning Procedures in Python
# 9370584 / 10380902.4
# 2506.16430: Leave No One Undermined: Policy Targeting with Regret Aversion
# 9647397 / 10380902.4
# 2504.14417: Reciprocating thermochemical mediator of pre-biotic polymer decomposition on mineral surfaces
# 9734249 / 10380902.4
# 2505.03753: An application of Gelfand's formula in approximating the roots of polynomials
# 9811023 / 10380902.4
# 2507.04211: Siberian radioheliograph image classification using ensemble of CLIP, EfficientNet and CatBoost models
# 9860824 / 10380902.4
# 2503.24257: Mathematical foundations of information economics
# 9864734 / 10380902.4
# 2506.16241: Relative Invertibility and Full Dualizability of Finite Braided Tensor Categories
# 10056851 / 10380902.4
# 2504.21201: General vector auxiliary differential equation finite-difference time-domain method for rotationally symmetric vector wave propagation in nonlinear optics
# 10058400 / 10380902.4
# 2505.06235: Metric Matrix in Barycentric Coordinates
# 10086262 / 10380902.4
# 2506.18001 - .bib error: 'etca'
# 2502.07935: $\texttt{PrecisionLauricella}$: package for numerical computation of Lauricella functions depending on a parameter
# 10172430 / 10380902.4
# 2506.18001: An Empirical Comparison of Weak-IV-Robust Procedures in Just-Identified Models
# 10228861 / 10380902.4
# 2504.21417: The Muon Collider
# 10493613 / 10380902.4
# 2507.04297: The median trick does not help for fully nested scrambling
# 292666 / 10380902.4
# 2507.01841: Automatic Rank Determination for Low-Rank Adaptation via Submodular Function Maximization
# 412606 / 10380902.4
# 2506.22424: Mesoscale properties of protein clusters determine the size and nature of liquid-liquid phase separation (LLPS)
# 414318 / 10380902.4
# 2503.07498: Optimal Diversification and Leverage in a Utility-Based Portfolio Allocation Approach
# 415477 / 10380902.4
# 2506.23350: On the Resilience of Underwater Semantic Wireless Communications
# 446661 / 10380902.4
# 2407.17586: Big5PersonalityEssays: Introducing a Novel Synthetic Generated Dataset Consisting of Short State-of-Consciousness Essays Annotated Based on the Five Factor Model of Personality
# 447826 / 10380902.4
# 2505.21661: KPerfIR: Towards an Open and Compiler-centric Ecosystem for GPU Kernel Performance Tooling on Modern AI Workloads
# 487841 / 10380902.4
# 2506.09966: Tight Paths and Tight Pairs in Weighted Directed Graphs
# 553356 / 10380902.4
# 1807.09515: Big Data: the End of the Scientific Method?
# 607185 / 10380902.4
# 2502.14256: A Unified Implementation of Quasi-Monte Carlo Generators, Randomization Routines, and Fast Kernel Methods
# 766659 / 10380902.4
# 2506.21978: Flat band excitons in a three-dimensional supertwisted spiral transition metal dichalcogenide
# 768773 / 10380902.4
# 2505.22668: On Characterizations of Convex and Approximately Subadditive Sequences
# 770284 / 10380902.4
# 2506.12429: Convexity in tensor triangular geometry
# 840671 / 10380902.4
# 2503.21973: Anomalous fermions
# 842060 / 10380902.4
# 2507.04339: NUTRIG: Development of a Novel Radio Self-Trigger for GRAND
# 878963 / 10380902.4
# 2507.01732: Gold after Randomized Sand: Model-X Split Knockoffs for Controlled Transformation Selection
# 915085 / 10380902.4
# 1907.01874: Challenges in IT Operations Management at a German University Chair -- Ten Years in Retrospect
# 965296 / 10380902.4
# 2506.10828: Coherence and Transients in Nonlocally Coupled Dissipative Kicked Rotors
# 1010992 / 10380902.4
# 2507.05483: Is Earendel a Star Cluster?: Metal Poor Globular Cluster Progenitors at $z\sim6$
# 1396821 / 10380902.4
# 2506.22614: On the Structure of Carbon Nanotubes: Results from Computer-Assisted Proofs
# 1542770 / 10380902.4
# 2506.18176: Perceptual multistability: a window for a multi-facet understanding of psychiatric disorders
# 1656431 / 10380902.4
# 2504.15809: A Line Graph-Based Framework for Identifying Optimal Routing Paths in Decentralized Exchanges
# 1708558 / 10380902.4
# 2506.18174: Duality and linearization for p-adic lie groups
# 2157058 / 10380902.4
# 2506.12398: Generalised Twisted Groupoids and their C*-algebras
# 2268653 / 10380902.4
# 2507.02159: Is the hyperscaling relation violated below the upper critical dimension in some particular cases?
# 2331276 / 10380902.4
# 2504.01964: What Can 240,000 New Credit Transactions Tell Us About the Impact of NGEU Funds?
# 2465124 / 10380902.4
# 2507.00998: Brown-Halmos type characterization for the tetrablock
# 2514821 / 10380902.4
# 2506.15066: ChatModel: Automating Reference Model Design and Verification with LLMs
# 2587356 / 10380902.4
# 2506.19128: Longitudinal analysis of heart rate variability as it pertains to anxiety and readiness
# 2640270 / 10380902.4
# 2506.07225: Active Lubrication of Transluminal Medical Instruments
# 2783996 / 10380902.4
# 2507.00443: Novel Pigeon-inspired 3D Obstacle Detection and Avoidance Maneuver for Multi-UAV Systems
# 2785625 / 10380902.4
# 2506.12961: Quantitative Relaxations of Arrow's Axioms
# 2831483 / 10380902.4
# 2506.11174: Large and iterated finite group actions on manifolds admitting non-zero degree maps to nilmanifolds
# 3038297 / 10380902.4
# 2503.24369: Exploring light propagation in nonlinear electrodynamics: phase and group velocities and related phenomena
# 3119472 / 10380902.4
# 2505.03835: The Shift Towards Preprints in AI Policy Research: A Comparative Study of Preprint Trends in the U.S., Europe, and South Korea
# 3121484 / 10380902.4
# 2502.11701: A Cholesky decomposition-based asset selection heuristic for sparse tangent portfolio optimization
# 3196554 / 10380902.4
# 2506.12228: Accuracy and Precision of Random Walk with Barrier Model Fitting: Simulations and Applications in Head and Neck Cancers
# 3198979 / 10380902.4
# 2505.08340: Imagination and Understanding through Astrophysical Imagery
# 3299853 / 10380902.4
# 2507.04775: FIDESlib: A Fully-Fledged Open-Source FHE Library for Efficient CKKS on GPUs
# 3332372 / 10380902.4
# 2506.23993: Half-metallicity and anomalous Slater-Pauling behaviour in half-Heusler CrMnSb
# 3334035 / 10380902.4
# 2507.04317: CLIP-RL: Surgical Scene Segmentation Using Contrastive Language-Vision Pretraining & Reinforcement Learning
# 3376149 / 10380902.4
# 2507.05176: Mass Proxy Quality of Massive Halo Properties in the IllustrisTNG and FLAMINGO Simulations: I. Hot Gas
# 3740798 / 10380902.4
# 2505.24183: CodeV-R1: Reasoning-Enhanced Verilog Generation
# 3780517 / 10380902.4
# 2507.07142: g2o vs. Ceres: Optimizing Scan Matching in Cartographer SLAM
# 3827248 / 10380902.4
# 2507.01787: From Reports to Reality: Testing Consistency in Instagram's Digital Services Act Compliance Data
# 4070068 / 10380902.4
# 2507.05323: SKYSURF-10: A Novel Method for Measuring Integrated Galaxy Light
# 4072249 / 10380902.4
# 2505.09773: Determining Magnetic Field Directions and Omni-directional Fluxes of Particles from STPSat-6 ZPS Plasma Measurements
# 4073817 / 10380902.4
# 2505.02941: Relativistic Toda lattice and equivariant $K$-homology
# 4075707 / 10380902.4
# 2506.18021: On the Robustness of Human-Object Interaction Detection against Distribution Shift
# 4169758 / 10380902.4
# 2501.15557: Preventing Household Bankruptcy: The One-Third Rule in Financial Planning with Mathematical Validation and Game-Theoretic Insights
# 4278678 / 10380902.4
# 2505.01771: Nonlinearization of the KdV-type and mKdV-type bilinear equations
# 4279495 / 10380902.4
# 2505.05012: Contact isotopies in the coherent-constructible correspondence
# 4381894 / 10380902.4
# 2505.03767: An affirmative answer to a problem of Cater
# 4389888 / 10380902.4
# 2506.12595: Leakage-Resilient Extractors against Number-on-Forehead Protocols
# 4521351 / 10380902.4
# 2412.19938: Towards Strong AI: Transformational Beliefs and Scientific Creativity
# 4684924 / 10380902.4
# 2507.03620: Is It Time To Treat Prompts As Code? A Multi-Use Case Study For Prompt Optimization Using DSPy
# 4742336 / 10380902.4
# 2503.22620: Math Matters of the Past (The Very First Mathematical Olympiads)
# 4801504 / 10380902.4
# 2505.06442: A linear-time algorithm to compute the conjugate of nonconvex bivariate piecewise linear-quadratic functions
# 4912186 / 10380902.4
# 2502.16015: On the computation of the cumulative distribution function of the Normal Inverse Gaussian distribution
# 5070037 / 10380902.4
# 2501.17366: Forecasting S&P 500 Using LSTM Models
# 5112180 / 10380902.4
# 2506.10660: Pushing the Limits of Extreme Weather: Constructing Extreme Heatwave Storylines with Differentiable Climate Models
# 5244583 / 10380902.4
