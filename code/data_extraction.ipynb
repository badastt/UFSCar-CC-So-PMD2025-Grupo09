# %%
import requests
import os
import tarfile
import bibtexparser
import arxiv
import json
import re
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
import shutil
import ssl
import certifi
import urllib.request


download_dir = "arxiv_downloads"
extracted_dir = "arxiv_extracted"
output_dir = "papers"
os.makedirs(download_dir, exist_ok=True)
os.makedirs(extracted_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

MAX_BYTES = 9.9 * 1024 * 1024
chunk_index = 0

ssl_context = ssl.create_default_context(cafile=certifi.where())
original_urlopen = urllib.request.urlopen

def patched_urlopen(url, *args, **kwargs):
    if 'context' not in kwargs:
        kwargs['context'] = ssl_context
    return original_urlopen(url, *args, **kwargs)

urllib.request.urlopen = patched_urlopen

mined = set()
all_paper_ids = set()

import logging

bibtex_logger = logging.getLogger('bibtexparser')
bibtex_logger.setLevel(logging.CRITICAL)
bibtex_logger.propagate = False

# %%
chunks = list(Path("papers").glob("data_chunk_*.ndjson"))
chunk_index += len(chunks)

for chunk in chunks:
    with open(chunk, 'r', encoding='utf-8') as f:
        papers = [json.loads(line) for line in f]
        for p in papers:
            mined.add(p["id"])

client = arxiv.Client()

categories = [
    "cs.AI", "cs.AR", "cs.CC", "cs.CE", "cs.CG", "cs.CL", "cs.CR", "cs.CV", "cs.CY", "cs.DB"
]

categories = [  
                "cs.AI", "cs.AR", "cs.CC", "cs.CE", "cs.CG", "cs.CL", "cs.CR", "cs.CV", "cs.CY", "cs.DB",
                "cs.DC", "cs.DL", "cs.DM", "cs.DS", "cs.ET", "cs.FL", "cs.GL", "cs.GR", "cs.GT", "cs.HC",
                "cs.IR", "cs.IT", "cs.LG", "cs.LO", "cs.MA", "cs.MM", "cs.MS", "cs.NA", "cs.NE", "cs.NI",
                "cs.OH", "cs.OS", "cs.PF", "cs.PL", "cs.RO", "cs.SC", "cs.SD", "cs.SE", "cs.SI", "cs.SY",
                "econ.EM", "econ.GN", "econ.TH", "eess.AS", "eess.IV", "eess.SP", "eess.SY", "math.AC", "math.AG", "math.AP",
                "math.AT", "math.CA", "math.CO", "math.CT", "math.CV", "math.DG", "math.DS", "math.FA", "math.GM", "math.GN",
                "math.GR", "math.GT", "math.HO", "math.IT", "math.KT", "math.LO", "math.MG", "math.MP", "math.NA", "math.NT",
                "math.OA", "math.OC", "math.PR", "math.QA", "math.RA", "math.RT", "math.SG", "math.SP", "math.ST", "astro-ph.CO",
                "astro-ph.EP", "astro-ph.GA", "astro-ph.HE", "astro-ph.IM", "astro-ph.SR", "cond-mat.dis-nn", "cond-mat.mes-hall", "cond-mat.mtrl-sci", "cond-mat.other",
                "cond-mat.quant-gas", "cond-mat.soft", "cond-mat.stat-mech", "cond-mat.str-el", "cond-mat.supr-con", "gr-qc", "hep-ex", "hep-lat", "hep-ph", "hep-th",
                "math-ph", "nlin.AO", "nlin.CD", "nlin.CG", "nlin.PS", "nlin.SI", "nucl-ex", "nucl-th", "physics.acc-ph", "physics.ao-ph",
                "physics.app-ph", "physics.atm-clus", "physics.atom-ph", "physics.bio-ph", "physics.chem-ph", "physics.class-ph", "physics.comp-ph", "physics.data-an", "physics.ed-ph", "physics.flu-dyn",
                "physics.gen-ph", "physics.geo-ph", "physics.hist-ph", "physics.ins-det", "physics.med-ph", "physics.optics", "physics.plasm-ph", "physics.pop-ph", "physics.soc-ph", "physics.space-ph",
                "quant-ph", "q-bio.BM", "q-bio.CB", "q-bio.GN", "q-bio.MN", "q-bio.NC", "q-bio.OT", "q-bio.PE", "q-bio.QM", "q-bio.SC",
                "q-bio.TO", "q-fin.CP", "q-fin.EC", "q-fin.GN", "q-fin.MF", "q-fin.PM", "q-fin.PR", "q-fin.RM", "q-fin.ST", "q-fin.TR",
                "stat.AP", "stat.CO", "stat.ME", "stat.ML", "stat.OT", "stat.TH"
            ]

categories = [  
                "cs.AI", "cs.AR", "cs.CC", "cs.CE", "cs.CG", "cs.CL", "cs.CR", "cs.CV", "cs.CY", "cs.DB",
                "cs.DC", "cs.DL", "cs.DM", "cs.DS", "cs.ET", "cs.FL", "cs.GL", "cs.GR", "cs.GT", "cs.HC",
                "cs.IR", "cs.IT", "cs.LG", "cs.LO", "cs.MA", "cs.MM", "cs.MS", "cs.NA", "cs.NE", "cs.NI",
                "cs.OH", "cs.OS", "cs.PF", "cs.PL", "cs.RO", "cs.SC", "cs.SD", "cs.SE", "cs.SI", "cs.SY",
            ]

for n, c in enumerate(categories, 1):
    print(f"Fetching IDs for category {n} / {len(categories)}: {c}")
    search = arxiv.Search(
        query = f"cat:{c}",
        max_results=500,
        sort_by=arxiv.SortCriterion.SubmittedDate
    )
    try:
        results = client.results(search)
        for paper in results:
            pid = paper.entry_id.rsplit('/', 1)[-1].rsplit('v', 1)[0]
            all_paper_ids.add(pid)
    except Exception as e:
        print(f"Error fetching from category {c}: {e}")

all_paper_ids -= mined

print(f"Total paper IDs collected after removing repeated or mined: {len(all_paper_ids)}")
# Out:
# Fetching IDs for category 1 / 40: cs.AI
# Error fetching from category cs.AI: Page of results was unexpectedly empty (https://export.arxiv.org/api/query?search_query=cat%3Acs.AI&id_list=&sortBy=submittedDate&sortOrder=descending&start=100&max_results=100)
# Fetching IDs for category 2 / 40: cs.AR
# Fetching IDs for category 3 / 40: cs.CC
# Fetching IDs for category 4 / 40: cs.CE
# Fetching IDs for category 5 / 40: cs.CG
# Fetching IDs for category 6 / 40: cs.CL
# Fetching IDs for category 7 / 40: cs.CR
# Fetching IDs for category 8 / 40: cs.CV
# Error fetching from category cs.CV: Page of results was unexpectedly empty (https://export.arxiv.org/api/query?search_query=cat%3Acs.CV&id_list=&sortBy=submittedDate&sortOrder=descending&start=400&max_results=100)
# Fetching IDs for category 9 / 40: cs.CY
# Fetching IDs for category 10 / 40: cs.DB
# Fetching IDs for category 11 / 40: cs.DC
# Fetching IDs for category 12 / 40: cs.DL
# Fetching IDs for category 13 / 40: cs.DM
# Fetching IDs for category 14 / 40: cs.DS
# Fetching IDs for category 15 / 40: cs.ET
# Fetching IDs for category 16 / 40: cs.FL
# Fetching IDs for category 17 / 40: cs.GL
# Fetching IDs for category 18 / 40: cs.GR
# Fetching IDs for category 19 / 40: cs.GT
# Fetching IDs for category 20 / 40: cs.HC
# Fetching IDs for category 21 / 40: cs.IR
# Fetching IDs for category 22 / 40: cs.IT
# Fetching IDs for category 23 / 40: cs.LG
# Error fetching from category cs.LG: Page of results was unexpectedly empty (https://export.arxiv.org/api/query?search_query=cat%3Acs.LG&id_list=&sortBy=submittedDate&sortOrder=descending&start=200&max_results=100)
# Fetching IDs for category 24 / 40: cs.LO
# Fetching IDs for category 25 / 40: cs.MA
# Fetching IDs for category 26 / 40: cs.MM
# Fetching IDs for category 27 / 40: cs.MS
# Fetching IDs for category 28 / 40: cs.NA
# Fetching IDs for category 29 / 40: cs.NE
# Fetching IDs for category 30 / 40: cs.NI
# Fetching IDs for category 31 / 40: cs.OH
# Fetching IDs for category 32 / 40: cs.OS
# Fetching IDs for category 33 / 40: cs.PF
# Fetching IDs for category 34 / 40: cs.PL
# Fetching IDs for category 35 / 40: cs.RO
# Fetching IDs for category 36 / 40: cs.SC
# Fetching IDs for category 37 / 40: cs.SD
# Fetching IDs for category 38 / 40: cs.SE
# Fetching IDs for category 39 / 40: cs.SI
# Fetching IDs for category 40 / 40: cs.SY
# Total paper IDs collected after removing repeated or mined: 2649

# %%
def process_paper(id):
    try:
        r = next(client.results(arxiv.Search(id_list=[id])))

        data = {}
        data['id'] = id
        data['link'] = r.entry_id
        data['last_update'] = r.updated.isoformat()
        data['published'] = r.published.isoformat()
        data['title'] = r.title
        data['authors'] = [str(a) for a in r.authors]
        data['summary'] = r.summary
        data['primary_category'] = r.primary_category
        data['categories'] = r.categories
        data['pre-print_link'] = f"http://arxiv.org/e-print/{id}"

        paper_path = os.path.join(download_dir, f"{id}.tar.gz")
        r.download_source(dirpath=download_dir, filename=f"{id}.tar.gz")

        extracted_path = os.path.join(extracted_dir, id)
        os.makedirs(extracted_path, exist_ok=True)

        try:
            with tarfile.open(paper_path, "r:gz") as tar:
                tar.extractall(path=extracted_path, filter='data')
    
            bib_entries = []
            for root, _, files in os.walk(extracted_path):
                for file in files:
                    if file.endswith('.bib'):
                        try:
                            with open(os.path.join(root, file), encoding='utf-8') as f:
                                parser = bibtexparser.bparser.BibTexParser(common_strings=True, ignore_nonstandard_types=True)
                                bib_db = bibtexparser.load(f, parser=parser)
                                bib_entries.extend(bib_db.entries)
                        except Exception as e:
                            print(f"{id} - .bib error: {e}")
            if bib_entries:
                data['bib'] = bib_entries
            else:
                for root, _, files in os.walk(extracted_path):
                    for file in files:
                        if file.endswith('.bbl'):
                            try:
                                with open(os.path.join(root, file), encoding='utf-8') as f:
                                    data['bbl'] = f.read()
                            except Exception as e:
                                print(f"{id} - .bbl error: {e}")
                            break
    
            for root, _, files in os.walk(extracted_path):
                for file in files:
                    if file.endswith('.tex'):
                        try:
                            with open(os.path.join(root, file), encoding='utf-8') as f:
                                tex = f.read()
                                if re.search(r"\*?\\documentclass\*?", tex):
                                    data['tex'] = tex
                                    break
                        except Exception as e:
                            print(f"{id} - .tex error: {e}")
        except:
            pass

        try:
            if os.path.exists(paper_path):
                os.remove(paper_path)
            if os.path.exists(extracted_path):
                shutil.rmtree(extracted_path)
        except Exception as e:
            print(f"{id} - cleanup error: {e}")

        return data

    except Exception as e:
        print(f"{id} - general error: {e}")
        return { "id": id, "error": str(e) }

all_data = {}

with ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(process_paper, pid) for pid in all_paper_ids]
    for future in as_completed(futures):
        result = future.result()
        pid = result.get("id", "[unknown]")

        if not result or "error" in result:
            continue
        
        if "error" not in result:
            all_data[pid] = result
            print(f"{pid}: {result.get('title', '[no title]')}")

            est_size = len(json.dumps(all_data, ensure_ascii=False).encode("utf-8"))

            print(f"{est_size} / {MAX_BYTES}")

            if est_size > MAX_BYTES and len(all_data) == 2:
                all_data = {pid: result}
                continue
            
            elif est_size > MAX_BYTES:
                all_data.pop(pid)
                filename = os.path.join(output_dir, f"data_chunk_{chunk_index:03d}.ndjson")
                with open(filename, "w", encoding="utf-8") as f:
                    for paper_id, metadata in all_data.items():
                        metadata["id"] = paper_id
                        json.dump(metadata, f)
                        f.write("\n")
                chunk_index += 1
                all_data = {pid: result}
# Out:
# 2507.08766: A Hybrid Multi-Well Hopfield-CNN with Feature Extraction and K-Means for MNIST Classification
# 47963 / 10380902.4
# 2506.22689: A new sparsity promoting residual transform operator for Lasso regression
# 136230 / 10380902.4
# 2506.23855: Differentially Private Synthetic Data Release for Topics API Outputs
# 283741 / 10380902.4
# 2506.00945: Constructions of Optimal Frequency-Hopping Sequences with Controlled Minimum Gaps
# 359086 / 10380902.4
# 2507.05255: Open Vision Reasoner: Transferring Linguistic Cognitive Behavior for Visual Reasoning
# 418414 / 10380902.4
# 2505.15154 - .bib error: 'cvprw'
# 2505.15154: Prolonged Reasoning Is Not All You Need: Certainty-Based Adaptive Routing for Efficient LLM/MLLM Reasoning
# 537478 / 10380902.4
# 2502.19603 - .bib error: 'aij'
# 2502.19603: Planning with Linear Temporal Logic Specifications: Handling Quantifiable and Unquantifiable Uncertainty
# 645466 / 10380902.4
# 2506.20966: Parallels Between VLA Model Post-Training and Human Motor Learning: Progress, Challenges, and Trends
# 810547 / 10380902.4
# 2507.01208: Deep Learning-Based Intrusion Detection for Automotive Ethernet: Evaluating & Optimizing Fast Inference Techniques for Deployment on Low-Cost Platform
# 875311 / 10380902.4
# 2501.00939: Navigating Knowledge: Patterns and Insights from Wikipedia Consumption
# 876521 / 10380902.4
# 2505.12399: Optimizing Interplanetary Trajectories using Hybrid Meta-heuristic
# 878801 / 10380902.4
# 2506.06728: Neighborhood Overlap-Aware High-Order Graph Neural Network for Dynamic Graph Learning
# 880452 / 10380902.4
# 2403.08656: Physical Memory Attacks and a Memory Safe Management System for Memory Defense
# 881738 / 10380902.4
# 2507.03293: LTLCrit: A Temporal Logic-based LLM Critic for Safe and Efficient Embodied Agents
# 966858 / 10380902.4
# 2505.16200: Advanced Integration Strategies for ESD Protection and Termination in High-Speed LVDS Systems
# 968215 / 10380902.4
# 2503.17387: On Nash Equilibria in Play-Once and Terminal Deterministic Graphical Games
# 969387 / 10380902.4
# 2505.08146: Tensor Sketch: Fast and Scalable Polynomial Kernel Approximation
# 1098552 / 10380902.4
# 2507.06531: ILNet: Trajectory Prediction with Inverse Learning Attention for Enhancing Intention Capture
# 1194030 / 10380902.4
# 2506.00332: Disentangling Codemixing in Chats: The NUS ABC Codemixed Corpus
# 1195596 / 10380902.4
# 2506.17934: A GenAI System for Improved FAIR Independent Biological Database Integration
# 1449267 / 10380902.4
# 2504.21291: Efficiency of Analysis of Transitive Relations using Query-Driven, Ground-and-Solve, and Fact-Driven Inference
# 1471578 / 10380902.4
# 2506.12792: Prosocial Design in Trust and Safety
# 1473001 / 10380902.4
# 2505.14519: Distributed quantum computing with black-box subroutines
# 1587630 / 10380902.4
# 2506.11781: GeoPandas-AI: A Smart Class Bringing LLM as Stateful AI Code Assistant
# 1700045 / 10380902.4
# 2411.09121: AutoQ 2.0: From Verification of Quantum Circuits to Verification of Quantum Programs
# 1952031 / 10380902.4
# 2507.08238: Self-Supervised Learning-Based Multimodal Prediction on Prosocial Behavior Intentions
# 1991266 / 10380902.4
# 0406022 - general error: Page request resulted in HTTP 400 (https://export.arxiv.org/api/query?search_query=&id_list=0406022&sortBy=relevance&sortOrder=descending&start=0&max_results=100)
# 2506.19164: GradualDiff-Fed: A Federated Learning Specialized Framework for Large Language Model
# 2031960 / 10380902.4
# 2506.06357: Cascaded Multiwire-PLC/Multiple-VLC System: Characterization and Performance
# 2109903 / 10380902.4
# 2502.07846: Memory Analysis on the Training Course of DeepSeek Models
# 2141761 / 10380902.4
# 2507.08110: AI Feedback Enhances Community-Based Content Moderation through Engagement with Counterarguments
# 2249169 / 10380902.4
# 2506.16574: Weight Factorization and Centralization for Continual Learning in Speech Recognition
# 2385758 / 10380902.4
# 2506.12756: Hierarchical Group-wise Ranking Framework for Recommendation Models
# 2451753 / 10380902.4
